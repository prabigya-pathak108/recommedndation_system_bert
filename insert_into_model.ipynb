# %%
import pandas as pd
from sqlalchemy.orm import Session
from database import engine, SessionLocal
from models.SmartPhone import SmartPhone

# Path to the CSV file
dataset_path = r"C:\Users\prabigya\Desktop\work_here\Recommendo-Personalized-Shopping-Powered-by-LLMs\load_into_database\dataset\clean_smartphone_data.csv"

def load_data_from_csv(csv_path):
    """Load data from CSV into the SmartPhone table."""
    # Read CSV into a DataFrame
    df = pd.read_csv(csv_path)
    # Step 2: Map CSV column names to SQLAlchemy model attributes
    column_mapping = {
    "brand_name": "brand_name",
    "model": "model",
    "price": "price",
    "avg_rating": "avg_rating",
    "5G_or_not": "is_5G",
    "processor_brand": "processor_brand",
    "num_cores": "num_cores",
    "processor_speed": "processor_speed",
    "battery_capacity": "battery_capacity",
    "fast_charging_available": "fast_charging_available",
    "fast_charging": "fast_charging",
    "ram_capacity": "ram_capacity",
    "internal_memory": "internal_memory",
    "screen_size": "screen_size",
    "refresh_rate": "refresh_rate",
    "num_rear_cameras": "num_rear_cameras",
    "os": "os",
    "primary_camera_rear": "primary_camera_rear",
    "primary_camera_front": "primary_camera_front",
    "extended_memory_available": "extended_memory_available",
    "resolution_height": "resolution_height",
    "resolution_width": "resolution_width",
}

# Step 3: Transform the DataFrame to match the database model structure
    df = df.rename(columns=column_mapping)

    # Convert boolean columns from string to boolean
    boolean_columns = ["is_5G", "fast_charging_available", "extended_memory_available"]
    for column in boolean_columns:
        df[column] = df[column].astype(bool)

    # Replace NaN with None for nullable columns
    df = df.where(pd.notnull(df), None)
    
    
    # Open a database session
    session = SessionLocal()
    
    
    
    # session = Session()

    try:
        # Iterate over DataFrame rows and insert into the database
        for _, row in df.iterrows():
            smartphone = SmartPhone(
                brand_name=row["brand_name"],
                model=row["model"],
                price=row["price"],
                avg_rating=row["avg_rating"],
                is_5G=row["is_5G"],
                processor_brand=row["processor_brand"],
                num_cores=row["num_cores"],
                processor_speed=row["processor_speed"],
                battery_capacity=row["battery_capacity"],
                fast_charging_available=row["fast_charging_available"],
                fast_charging=row["fast_charging"],
                ram_capacity=row["ram_capacity"],
                internal_memory=row["internal_memory"],
                screen_size=row["screen_size"],
                refresh_rate=row["refresh_rate"],
                num_rear_cameras=row["num_rear_cameras"],
                os=row["os"],
                primary_camera_rear=row["primary_camera_rear"],
                primary_camera_front=row["primary_camera_front"],
                extended_memory_available=row["extended_memory_available"],
                resolution_height=row["resolution_height"],
                resolution_width=row["resolution_width"],
            )
            session.add(smartphone)

        # Commit the transaction
        session.commit()
        print("Data inserted successfully!")

    except Exception as e:
        # Rollback in case of any error
        session.rollback()
        print("Error occurred:", e)

# if __name__ == "__main__":
#     load_data_from_csv(dataset_path)
# Out:
# 2025-01-15 22:46:06,157 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-01-15 22:46:06,204 INFO sqlalchemy.engine.Engine INSERT INTO smartphone (brand_name, model, price, avg_rating, "is_5G", processor_brand, num_cores, processor_speed, battery_capacity, fast_charging_available, fast_charging, ram_capacity, internal_memory, screen_size, refresh_rate, num_rear_cameras, os, primary_camera_rear, primary_camera_front, extended_memory_available, resolution_height, resolution_width) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 22:46:06,208 INFO sqlalchemy.engine.Engine [generated in 0.01409s (insertmanyvalues) 1/638 (ordered; batch not supported)] ('apple', 'Apple iPhone 11', 255580, 7.3, 0, 'bionic', 6.0, 2.65, 3110.0, 0, nan, 4, 64, 6.1, 60, 2, 'ios', 12.0, 12.0, 0, 1792, 828)
# 2025-01-15 22:46:06,219 INFO sqlalchemy.engine.Engine INSERT INTO smartphone (brand_name, model, price, avg_rating, "is_5G", processor_brand, num_cores, processor_speed, battery_capacity, fast_charging_available, fast_charging, ram_capacity, internal_memory, screen_size, refresh_rate, num_rear_cameras, os, primary_camera_rear, primary_camera_front, extended_memory_available, resolution_height, resolution_width) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 22:46:06,220 INFO sqlalchemy.engine.Engine [insertmanyvalues 2/638 (ordered; batch not supported)] ('apple', 'Apple iPhone 11 (128GB)', 308020, 7.5, 0, 'bionic', 6.0, 2.65, 3110.0, 0, nan, 4, 128, 6.1, 60, 2, 'ios', 12.0, 12.0, 0, 1792, 828)
# 2025-01-15 22:46:06,221 INFO sqlalchemy.engine.Engine INSERT INTO smartphone (brand_name, model, price, avg_rating, "is_5G", processor_brand, num_cores, processor_speed, battery_capacity, fast_charging_available, fast_charging, ram_capacity, internal_memory, screen_size, refresh_rate, num_rear_cameras, os, primary_camera_rear, primary_camera_front, extended_memory_available, resolution_height, resolution_width) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 22:46:06,223 INFO sqlalchemy.engine.Engine [insertmanyvalues 3/638 (ordered; batch not supported)] ('apple', 'Apple iPhone 11 Pro Max', 720220, 7.7, 0, 'bionic', 6.0, 2.65, 3500.0, 1, 18.0, 4, 64, 6.5, 60, 3, 'ios', 12.0, 12.0, 0, 2688, 1242)
# 2025-01-15 22:46:06,225 INFO sqlalchemy.engine.Engine INSERT INTO smartphone (brand_name, model, price, avg_rating, "is_5G", processor_brand, num_cores, processor_speed, battery_capacity, fast_charging_available, fast_charging, ram_capacity, internal_memory, screen_size, refresh_rate, num_rear_cameras, os, primary_camera_rear, primary_camera_front, extended_memory_available, resolution_height, resolution_width) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 22:46:06,226 INFO sqlalchemy.engine.Engine [insertmanyvalues 4/638 (ordered; batch not supported)] ('apple', 'Apple iPhone 12', 340780, 7.4, 1, 'bionic', 6.0, 3.1, nan, 0, nan, 4, 64, 6.1, 60, 2, 'ios', 12.0, 12.0, 0, 2532, 1170)
# 2025-01-15 22:46:06,227 INFO sqlalchemy.engine.Engine INSERT INTO smartphone (brand_name, model, price, avg_rating, "is_5G", processor_brand, num_cores, processor_speed, battery_capacity, fast_charging_available, fast_charging, ram_capacity, internal_memory, screen_size, refresh_rate, num_rear_cameras, os, primary_camera_rear, primary_camera_front, extended_memory_available, resolution_height, resolution_width) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 22:46:06,228 INFO sqlalchemy.engine.Engine [insertmanyvalues 5/638 (ordered; batch not supported)] ('apple', 'Apple iPhone 12 (128GB)', 367010, 7.5, 1, 'bionic', 6.0, 3.1, nan, 0, nan, 4, 128, 6.1, 60, 2, 'ios', 12.0, 12.0, 0, 2532, 1170)
# 2025-01-15 22:46:06,230 INFO sqlalchemy.engine.Engine INSERT INTO smartphone (brand_name, model, price, avg_rating, "is_5G", processor_brand, num_cores, processor_speed, battery_capacity, fast_charging_available, fast_charging, ram_capacity, internal_memory, screen_size, refresh_rate, num_rear_cameras, os, primary_camera_rear, primary_camera_front, extended_memory_available, resolution_height, resolution_width) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 22:46:06,231 INFO sqlalchemy.engine.Engine [insertmanyvalues 6/638 (ordered; batch not supported)] ('apple', 'Apple iPhone 12 (256GB)', 445650, 7.6, 1, 'bionic', 6.0, 3.1, nan, 0, nan, 4, 256, 6.1, 60, 2, 'ios', 12.0, 12.0, 0, 2532, 1170)
# 2025-01-15 22:46:06,232 INFO sqlalchemy.engine.Engine INSERT INTO smartphone (brand_name, model, price, avg_rating, "is_5G", processor_brand, num_cores, processor_speed, battery_capacity, fast_charging_available, fast_charging, ram_capacity, internal_memory, screen_size, refresh_rate, num_rear_cameras, os, primary_camera_rear, primary_camera_front, extended_memory_available, resolution_height, resolution_width) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 22:46:06,234 INFO sqlalchemy.engine.Engine [insertmanyvalues 7/638 (ordered; batch not supported)] ('apple', 'Apple iPhone 12 Mini', 268700, 7.4, 1, 'bionic', 6.0, 3.1, nan, 0, nan, 4, 64, 5.4, 60, 2, 'ios', 12.0, 12.0, 0, 2340, 1080)
# 2025-01-15 22:46:06,235 INFO sqlalchemy.engine.Engine INSERT INTO smartphone (brand_name, model, price, avg_rating, "is_5G", processor_brand, num_cores, processor_speed, battery_capacity, fast_charging_available, fast_charging, ram_capacity, internal_memory, screen_size, refresh_rate, num_rear_cameras, os, primary_camera_rear, primary_camera_front, extended_memory_available, resolution_height, resolution_width) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 22:46:06,236 INFO sqlalchemy.engine.Engine [insertmanyvalues 8/638 (ordered; batch not supported)] ('apple', 'Apple iPhone 12 Mini (128GB)', 301470, 7.5, 1, 'bionic', 6.0, 3.1, nan, 0, nan, 4, 128, 5.4, 60, 2, 'ios', 12.0, 12.0, 0, 2340, 1080)
# 2025-01-15 22:46:06,237 INFO sqlalchemy.engine.Engine INSERT INTO smartphone (brand_name, model, price, avg_rating, "is_5G", processor_brand, num_cores, processor_speed, battery_capacity, fast_charging_available, fast_charging, ram_capacity, internal_memory, screen_size, refresh_rate, num_rear_cameras, os, primary_camera_rear, primary_camera_front, extended_memory_available, resolution_height, resolution_width) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 22:46:06,239 INFO sqlalchemy.engine.Engine [insertmanyvalues 9/638 (ordered; batch not supported)] ('apple', 'Apple iPhone 12 Mini (256GB)', 367010, 7.5, 1, 'bionic', 6.0, 3.1, nan, 0, nan, 4, 256, 5.4, 60, 2, 'ios', 12.0, 12.0, 0, 2340, 1080)
# 2025-01-15 22:46:06,241 INFO sqlalchemy.engine.Engine INSERT INTO smartphone (brand_name, model, price, avg_rating, "is_5G", processor_brand, num_cores, processor_speed, battery_capacity, fast_charging_available, fast_charging, ram_capacity, internal_memory, screen_size, refresh_rate, num_rear_cameras, os, primary_camera_rear, primary_camera_front, extended_memory_available, resolution_height, resolution_width) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 22:46:06,241 INFO sqlalchemy.engine.Engine [insertmanyvalues 10/638 (ordered; batch not supported)] ('apple', 'Apple iPhone 12 Pro (256GB)', 785760, 8.0, 1, 'bionic', 6.0, 3.1, nan, 0, nan, 6, 256, 6.1, 60, 3, 'ios', 12.0, 12.0, 0, 2532, 1170)
# 2025-01-15 22:46:06,243 INFO sqlalchemy.engine.Engine INSERT INTO smartphone (brand_name, model, price, avg_rating, "is_5G", processor_brand, num_cores, processor_speed, battery_capacity, fast_charging_available, fast_charging, ram_capacity, internal_memory, screen_size, refresh_rate, num_rear_cameras, os, primary_camera_rear, primary_camera_front, extended_memory_available, resolution_height, resolution_width) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 22:46:06,244 INFO sqlalchemy.engine.Engine [insertmanyvalues 11/638 (ordered; batch not supported)] ('apple', 'Apple iPhone 12 Pro (512GB)', 916830, 8.0, 1, 'bionic', 6.0, 3.1, nan, 0, nan, 6, 512, 6.1, 60, 3, 'ios', 12.0, 12.0, 0, 2532, 1170)
# 2025-01-15 22:46:06,246 INFO sqlalchemy.engine.Engine INSERT INTO smartphone (brand_name, model, price, avg_rating, "is_5G", processor_brand, num_cores, processor_speed, battery_capacity, fast_charging_available, fast_charging, ram_capacity, internal_memory, screen_size, refresh_rate, num_rear_cameras, os, primary_camera_rear, primary_camera_front, extended_memory_available, resolution_height, resolution_width) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 22:46:06,247 INFO sqlalchemy.engine.Engine [insertmanyvalues 12/638 (ordered; batch not supported)] ('apple', 'Apple iPhone 13', 412880, 7.9, 1, 'bionic', 6.0, 3.22, 3240.0, 1, nan, 4, 128, 6.1, 60, 2, 'ios', 12.0, 12.0, 0, 2532, 1170)
# 2025-01-15 22:46:06,248 INFO sqlalchemy.engine.Engine INSERT INTO smartphone (brand_name, model, price, avg_rating, "is_5G", processor_brand, num_cores, processor_speed, battery_capacity, fast_charging_available, fast_charging, ram_capacity, internal_memory, screen_size, refresh_rate, num_rear_cameras, os, primary_camera_rear, primary_camera_front, extended_memory_available, resolution_height, resolution_width) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 22:46:06,249 INFO sqlalchemy.engine.Engine [insertmanyvalues 13/638 (ordered; batch not supported)] ('apple', 'Apple iPhone 13 (256GB)', 478420, 7.9, 1, 'bionic', 6.0, 3.22, 3240.0, 1, nan, 4, 256, 6.1, 60, 2, 'ios', 12.0, 12.0, 0, 2532, 1170)
# 2025-01-15 22:46:06,251 INFO sqlalchemy.engine.Engine INSERT INTO smartphone (brand_name, model, price, avg_rating, "is_5G", processor_brand, num_cores, processor_speed, battery_capacity, fast_charging_available, fast_charging, ram_capacity, internal_memory, screen_size, refresh_rate, num_rear_cameras, os, primary_camera_rear, primary_camera_front, extended_memory_available, resolution_height, resolution_width) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 22:46:06,252 INFO sqlalchemy.engine.Engine [insertmanyvalues 14/638 (ordered; batch not supported)] ('apple', 'Apple iPhone 13 (512GB)', 602930, 8.0, 1, 'bionic', 6.0, 3.22, 3240.0, 1, nan, 4, 512, 6.1, 60, 2, 'ios', 12.0, 12.0, 0, 2532, 1170)
# 2025-01-15 22:46:06,255 INFO sqlalchemy.engine.Engine INSERT INTO smartphone (brand_name, model, price, avg_rating, "is_5G", processor_brand, num_cores, processor_speed, battery_capacity, fast_charging_available, fast_charging, ram_capacity, internal_memory, screen_size, refresh_rate, num_rear_cameras, os, primary_camera_rear, primary_camera_front, extended_memory_available, resolution_height, resolution_width) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 22:46:06,256 INFO sqlalchemy.engine.Engine [insertmanyvalues 15/638 (ordered; batch not supported)] ('apple', 'Apple iPhone 13 Mini', 425310, 7.9, 1, 'bionic', 6.0, 3.22, 2438.0, 1, nan, 4, 128, 5.4, 60, 2, 'ios', 12.0, 12.0, 0, 2340, 1080)
# 2025-01-15 22:46:06,257 INFO sqlalchemy.engine.Engine INSERT INTO smartphone (brand_name, model, price, avg_rating, "is_5G", processor_brand, num_cores, processor_speed, battery_capacity, fast_charging_available, fast_charging, ram_capacity, internal_memory, screen_size, refresh_rate, num_rear_cameras, os, primary_camera_rear, primary_camera_front, extended_memory_available, resolution_height, resolution_width) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 22:46:06,258 INFO sqlalchemy.engine.Engine [insertmanyvalues 16/638 (ordered; batch not supported)] ('apple', 'Apple iPhone 13 Pro', 785760, 8.3, 1, 'bionic', 6.0, 3.22, 3095.0, 1, nan, 6, 128, 6.1, 120, 3, 'ios', 12.0, 12.0, 0, 2532, 1170)
# 2025-01-15 22:46:06,260 INFO sqlalchemy.engine.Engine INSERT INTO smartphone (brand_name, model, price, avg_rating, "is_5G", processor_brand, num_cores, processor_speed, battery_capacity, fast_charging_available, fast_charging, ram_capacity, internal_memory, screen_size, refresh_rate, num_rear_cameras, os, primary_camera_rear, primary_camera_front, extended_memory_available, resolution_height, resolution_width) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 22:46:06,261 INFO sqlalchemy.engine.Engine [insertmanyvalues 17/638 (ordered; batch not supported)] ('apple', 'Apple iPhone 13 Pro (1TB)', 969260, 8.4, 1, 'bionic', 6.0, 3.22, 3095.0, 1, nan, 6, 1024, 6.1, 120, 3, 'ios', 12.0, 12.0, 0, 2532, 1170)
# 2025-01-15 22:46:06,263 INFO sqlalchemy.engine.Engine INSERT INTO smartphone (brand_name, model, price, avg_rating, "is_5G", processor_brand, num_cores, processor_speed, battery_capacity, fast_charging_available, fast_charging, ram_capacity, internal_memory, screen_size, refresh_rate, num_rear_cameras, os, primary_camera_rear, primary_camera_front, extended_memory_available, resolution_height, resolution_width) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 22:46:06,265 INFO sqlalchemy.engine.Engine [insertmanyvalues 18/638 (ordered; batch not supported)] ('apple', 'Apple iPhone 13 Pro (256GB)', 851300, 8.3, 1, 'bionic', 6.0, 3.22, 3095.0, 1, nan, 6, 256, 6.1, 120, 3, 'ios', 12.0, 12.0, 0, 2532, 1170)
# 2025-01-15 22:46:06,267 INFO sqlalchemy.engine.Engine INSERT INTO smartphone (brand_name, model, price, avg_rating, "is_5G", processor_brand, num_cores, processor_speed, battery_capacity, fast_charging_available, fast_charging, ram_capacity, internal_memory, screen_size, refresh_rate, num_rear_cameras, os, primary_camera_rear, primary_camera_front, extended_memory_available, resolution_height, resolution_width) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 22:46:06,269 INFO sqlalchemy.engine.Engine [insertmanyvalues 19/638 (ordered; batch not supported)] ('apple', 'Apple iPhone 13 Pro Max', 851300, 8.4, 1, 'bionic', 6.0, 3.22, 4352.0, 1, nan, 6, 128, 6.7, 120, 3, 'ios', 12.0, 12.0, 0, 2778, 1284)
# 2025-01-15 22:46:06,271 INFO sqlalchemy.engine.Engine INSERT INTO smartphone (brand_name, model, price, avg_rating, "is_5G", processor_brand, num_cores, processor_speed, battery_capacity, fast_charging_available, fast_charging, ram_capacity, internal_memory, screen_size, refresh_rate, num_rear_cameras, os, primary_camera_rear, primary_camera_front, extended_memory_available, resolution_height, resolution_width) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 22:46:06,273 INFO sqlalchemy.engine.Engine [insertmanyvalues 20/638 (ordered; batch not supported)] ('apple', 'Apple iPhone 13 Pro Max (1TB)', 1178980, 8.6, 1, 'bionic', 6.0, 3.22, 4352.0, 1, nan, 6, 1024, 6.7, 120, 3, 'ios', 12.0, 12.0, 0, 2778, 1284)
# 2025-01-15 22:46:06,274 INFO sqlalchemy.engine.Engine INSERT INTO smartphone (brand_name, model, price, avg_rating, "is_5G", processor_brand, num_cores, processor_speed, battery_capacity, fast_charging_available, fast_charging, ram_capacity, internal_memory, screen_size, refresh_rate, num_rear_cameras, os, primary_camera_rear, primary_camera_front, extended_memory_available, resolution_height, resolution_width) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 22:46:06,275 INFO sqlalchemy.engine.Engine [insertmanyvalues 21/638 (ordered; batch not supported)] ('apple', 'Apple iPhone 13 Pro Max (256GB)', 916830, 8.4, 1, 'bionic', 6.0, 3.22, 4352.0, 1, nan, 6, 256, 6.7, 120, 3, 'ios', 12.0, 12.0, 0, 2778, 1284)
# 2025-01-15 22:46:06,276 INFO sqlalchemy.engine.Engine INSERT INTO smartphone (brand_name, model, price, avg_rating, "is_5G", processor_brand, num_cores, processor_speed, battery_capacity, fast_charging_available, fast_charging, ram_capacity, internal_memory, screen_size, refresh_rate, num_rear_cameras, os, primary_camera_rear, primary_camera_front, extended_memory_available, resolution_height, resolution_width) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 22:46:06,277 INFO sqlalchemy.engine.Engine [insertmanyvalues 22/638 (ordered; batch not supported)] ('apple', 'Apple iPhone 14', 432540, 8.1, 1, 'bionic', 6.0, 3.22, 3279.0, 1, nan, 6, 128, 6.1, 60, 2, 'ios', 12.0, 12.0, 0, 2532, 1170)
# 2025-01-15 22:46:06,281 INFO sqlalchemy.engine.Engine INSERT INTO smartphone (brand_name, model, price, avg_rating, "is_5G", processor_brand, num_cores, processor_speed, battery_capacity, fast_charging_available, fast_charging, ram_capacity, internal_memory, screen_size, refresh_rate, num_rear_cameras, os, primary_camera_rear, primary_camera_front, extended_memory_available, resolution_height, resolution_width) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 22:46:06,283 INFO sqlalchemy.engine.Engine [insertmanyvalues 23/638 (ordered; batch not supported)] ('apple', 'Apple iPhone 14 (256GB)', 498080, 8.2, 1, 'bionic', 6.0, 3.22, 3279.0, 1, nan, 6, 256, 6.1, 60, 2, 'ios', 12.0, 12.0, 0, 2532, 1170)
# 2025-01-15 22:46:06,286 INFO sqlalchemy.engine.Engine INSERT INTO smartphone (brand_name, model, price, avg_rating, "is_5G", processor_brand, num_cores, processor_speed, battery_capacity, fast_charging_available, fast_charging, ram_capacity, internal_memory, screen_size, refresh_rate, num_rear_cameras, os, primary_camera_rear, primary_camera_front, extended_memory_available, resolution_height, resolution_width) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 22:46:06,288 INFO sqlalchemy.engine.Engine [insertmanyvalues 24/638 (ordered; batch not supported)] ('apple', 'Apple iPhone 14 (512GB)', 629150, 8.2, 1, 'bionic', 6.0, 3.22, 3279.0, 1, nan, 6, 512, 6.1, 60, 2, 'ios', 12.0, 12.0, 0, 2532, 1170)
# 2025-01-15 22:46:06,290 INFO sqlalchemy.engine.Engine INSERT INTO smartphone (brand_name, model, price, avg_rating, "is_5G", processor_brand, num_cores, processor_speed, battery_capacity, fast_charging_available, fast_charging, ram_capacity, internal_memory, screen_size, refresh_rate, num_rear_cameras, os, primary_camera_rear, primary_camera_front, extended_memory_available, resolution_height, resolution_width) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 22:46:06,292 INFO sqlalchemy.engine.Engine [insertmanyvalues 25/638 (ordered; batch not supported)] ('apple', 'Apple iPhone 14 Mini', 458670, 7.0, 0, 'bionic', nan, nan, 3500.0, 1, nan, 6, 128, 5.42, 60, 2, 'ios', 12.0, 12.0, 0, 2340, 1080)
# 2025-01-15 22:46:06,294 INFO sqlalchemy.engine.Engine INSERT INTO smartphone (brand_name, model, price, avg_rating, "is_5G", processor_brand, num_cores, processor_speed, battery_capacity, fast_charging_available, fast_charging, ram_capacity, internal_memory, screen_size, refresh_rate, num_rear_cameras, os, primary_camera_rear, primary_camera_front, extended_memory_available, resolution_height, resolution_width) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 22:46:06,297 INFO sqlalchemy.engine.Engine [insertmanyvalues 26/638 (ordered; batch not supported)] ('apple', 'Apple iPhone 14 Plus', 491520, 8.2, 1, 'bionic', 6.0, 3.22, 4325.0, 1, nan, 6, 128, 6.7, 60, 2, 'ios', 12.0, 12.0, 0, 2778, 1284)
# 2025-01-15 22:46:06,298 INFO sqlalchemy.engine.Engine INSERT INTO smartphone (brand_name, model, price, avg_rating, "is_5G", processor_brand, num_cores, processor_speed, battery_capacity, fast_charging_available, fast_charging, ram_capacity, internal_memory, screen_size, refresh_rate, num_rear_cameras, os, primary_camera_rear, primary_camera_front, extended_memory_available, resolution_height, resolution_width) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 22:46:06,301 INFO sqlalchemy.engine.Engine [insertmanyvalues 27/638 (ordered; batch not supported)] ('apple', 'Apple iPhone 14 Plus (256GB)', 557060, 8.3, 1, 'bionic', 6.0, 3.22, 4325.0, 1, nan, 6, 256, 6.7, 60, 2, 'ios', 12.0, 12.0, 0, 2778, 1284)
# 2025-01-15 22:46:06,303 INFO sqlalchemy.engine.Engine INSERT INTO smartphone (brand_name, model, price, avg_rating, "is_5G", processor_brand, num_cores, processor_speed, battery_capacity, fast_charging_available, fast_charging, ram_capacity, internal_memory, screen_size, refresh_rate, num_rear_cameras, os, primary_camera_rear, primary_camera_front, extended_memory_available, resolution_height, resolution_width) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 22:46:06,312 INFO sqlalchemy.engine.Engine [insertmanyvalues 28/638 (ordered; batch not supported)] ('apple', 'Apple iPhone 14 Plus (512GB)', 688130, 8.3, 1, 'bionic', 6.0, 3.22, 4325.0, 1, nan, 6, 512, 6.7, 60, 2, 'ios', 12.0, 12.0, 0, 2778, 1284)
# 2025-01-15 22:46:06,319 INFO sqlalchemy.engine.Engine INSERT INTO smartphone (brand_name, model, price, avg_rating, "is_5G", processor_brand, num_cores, processor_speed, battery_capacity, fast_charging_available, fast_charging, ram_capacity, internal_memory, screen_size, refresh_rate, num_rear_cameras, os, primary_camera_rear, primary_camera_front, extended_memory_available, resolution_height, resolution_width) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 22:46:06,333 INFO sqlalchemy.engine.Engine [insertmanyvalues 29/638 (ordered; batch not supported)] ('apple', 'Apple iPhone 14 Pro', 786350, 7.5, 1, 'bionic', 6.0, nan, 3200.0, 1, nan, 6, 128, 6.1, 120, 3, 'ios', 48.0, 12.0, 0, 2556, 1179)
# 2025-01-15 22:46:06,337 INFO sqlalchemy.engine.Engine INSERT INTO smartphone (brand_name, model, price, avg_rating, "is_5G", processor_brand, num_cores, processor_speed, battery_capacity, fast_charging_available, fast_charging, ram_capacity, internal_memory, screen_size, refresh_rate, num_rear_cameras, os, primary_camera_rear, primary_camera_front, extended_memory_available, resolution_height, resolution_width) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 22:46:06,348 INFO sqlalchemy.engine.Engine [insertmanyvalues 30/638 (ordered; batch not supported)] ('apple', 'Apple iPhone 14 Pro (1TB)', 1133780, 7.7, 1, 'bionic', 6.0, nan, 3200.0, 1, nan, 6, 1024, 6.1, 120, 3, 'ios', 48.0, 12.0, 0, 2556, 1179)
# 2025-01-15 22:46:06,352 INFO sqlalchemy.engine.Engine INSERT INTO smartphone (brand_name, model, price, avg_rating, "is_5G", processor_brand, num_cores, processor_speed, battery_capacity, fast_charging_available, fast_charging, ram_capacity, internal_memory, screen_size, refresh_rate, num_rear_cameras, os, primary_camera_rear, primary_camera_front, extended_memory_available, resolution_height, resolution_width) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 22:46:06,354 INFO sqlalchemy.engine.Engine [insertmanyvalues 31/638 (ordered; batch not supported)] ('apple', 'Apple iPhone 14 Pro (256GB)', 851890, 7.6, 1, 'bionic', 6.0, nan, 3200.0, 1, nan, 6, 256, 6.1, 120, 3, 'ios', 48.0, 12.0, 0, 2556, 1179)
# 2025-01-15 22:46:06,357 INFO sqlalchemy.engine.Engine INSERT INTO smartphone (brand_name, model, price, avg_rating, "is_5G", processor_brand, num_cores, processor_speed, battery_capacity, fast_charging_available, fast_charging, ram_capacity, internal_memory, screen_size, refresh_rate, num_rear_cameras, os, primary_camera_rear, primary_camera_front, extended_memory_available, resolution_height, resolution_width) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 22:46:06,358 INFO sqlalchemy.engine.Engine [insertmanyvalues 32/638 (ordered; batch not supported)] ('apple', 'Apple iPhone 14 Pro Max', 851890, 7.6, 1, 'bionic', 6.0, nan, 4323.0, 1, nan, 6, 128, 6.7, 120, 3, 'ios', 48.0, 12.0, 0, 2796, 1290)
# 2025-01-15 22:46:06,358 INFO sqlalchemy.engine.Engine INSERT INTO smartphone (brand_name, model, price, avg_rating, "is_5G", processor_brand, num_cores, processor_speed, battery_capacity, fast_charging_available, fast_charging, ram_capacity, internal_memory, screen_size, refresh_rate, num_rear_cameras, os, primary_camera_rear, primary_camera_front, extended_memory_available, resolution_height, resolution_width) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 22:46:06,358 INFO sqlalchemy.engine.Engine [insertmanyvalues 33/638 (ordered; batch not supported)] ('apple', 'Apple iPhone 14 Pro Max (1TB)', 1199310, 7.8, 1, 'bionic', 6.0, nan, 4323.0, 1, nan, 6, 1024, 6.7, 120, 3, 'ios', 48.0, 12.0, 0, 2796, 1290)
# 2025-01-15 22:46:06,358 INFO sqlalchemy.engine.Engine INSERT INTO smartphone (brand_name, model, price, avg_rating, "is_5G", processor_brand, num_cores, processor_speed, battery_capacity, fast_charging_available, fast_charging, ram_capacity, internal_memory, screen_size, refresh_rate, num_rear_cameras, os, primary_camera_rear, primary_camera_front, extended_memory_available, resolution_height, resolution_width) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 22:46:06,358 INFO sqlalchemy.engine.Engine [insertmanyvalues 34/638 (ordered; batch not supported)] ('apple', 'Apple iPhone 14 Pro Max (256GB)', 917420, 7.7, 1, 'bionic', 6.0, nan, 4323.0, 1, nan, 6, 256, 6.7, 120, 3, 'ios', 48.0, 12.0, 0, 2796, 1290)
# 2025-01-15 22:46:06,358 INFO sqlalchemy.engine.Engine INSERT INTO smartphone (brand_name, model, price, avg_rating, "is_5G", processor_brand, num_cores, processor_speed, battery_capacity, fast_charging_available, fast_charging, ram_capacity, internal_memory, screen_size, refresh_rate, num_rear_cameras, os, primary_camera_rear, primary_camera_front, extended_memory_available, resolution_height, resolution_width) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 22:46:06,358 INFO sqlalchemy.engine.Engine [insertmanyvalues 35/638 (ordered; batch not supported)] ('apple', 'Apple iPhone 14 Pro Max (512GB)', 1113440, 7.8, 1, 'bionic', 6.0, nan, 4323.0, 1, nan, 6, 512, 6.7, 120, 3, 'ios', 48.0, 12.0, 0, 2796, 1290)
# 2025-01-15 22:46:06,358 INFO sqlalchemy.engine.Engine INSERT INTO smartphone (brand_name, model, price, avg_rating, "is_5G", processor_brand, num_cores, processor_speed, battery_capacity, fast_charging_available, fast_charging, ram_capacity, internal_memory, screen_size, refresh_rate, num_rear_cameras, os, primary_camera_rear, primary_camera_front, extended_memory_available, resolution_height, resolution_width) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 22:46:06,374 INFO sqlalchemy.engine.Engine [insertmanyvalues 36/638 (ordered; batch not supported)] ('apple', 'Apple iPhone 15', 543870, 7.2, 0, 'bionic', nan, nan, 3285.0, 1, nan, 6, 128, 6.06, 60, 2, 'ios', 50.0, 13.0, 0, 2532, 1170)
# 2025-01-15 22:46:06,374 INFO sqlalchemy.engine.Engine INSERT INTO smartphone (brand_name, model, price, avg_rating, "is_5G", processor_brand, num_cores, processor_speed, battery_capacity, fast_charging_available, fast_charging, ram_capacity, internal_memory, screen_size, refresh_rate, num_rear_cameras, os, primary_camera_rear, primary_camera_front, extended_memory_available, resolution_height, resolution_width) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 22:46:06,374 INFO sqlalchemy.engine.Engine [insertmanyvalues 37/638 (ordered; batch not supported)] ('apple', 'Apple iPhone 15 Plus', 556980, 7.5, 1, 'bionic', 6.0, nan, 4532.0, 1, nan, 8, 128, 6.71, 120, 2, 'ios', 12.0, 12.0, 0, 2778, 1284)
# 2025-01-15 22:46:06,374 INFO sqlalchemy.engine.Engine INSERT INTO smartphone (brand_name, model, price, avg_rating, "is_5G", processor_brand, num_cores, processor_speed, battery_capacity, fast_charging_available, fast_charging, ram_capacity, internal_memory, screen_size, refresh_rate, num_rear_cameras, os, primary_camera_rear, primary_camera_front, extended_memory_available, resolution_height, resolution_width) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 22:46:06,374 INFO sqlalchemy.engine.Engine [insertmanyvalues 38/638 (ordered; batch not supported)] ('apple', 'Apple iPhone 15 Pro', 858450, 7.5, 1, 'bionic', nan, nan, nan, 0, nan, 8, 128, 6.06, 120, 3, 'ios', 50.0, 12.0, 0, 2532, 1170)
# 2025-01-15 22:46:06,374 INFO sqlalchemy.engine.Engine INSERT INTO smartphone (brand_name, model, price, avg_rating, "is_5G", processor_brand, num_cores, processor_speed, battery_capacity, fast_charging_available, fast_charging, ram_capacity, internal_memory, screen_size, refresh_rate, num_rear_cameras, os, primary_camera_rear, primary_camera_front, extended_memory_available, resolution_height, resolution_width) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 22:46:06,405 INFO sqlalchemy.engine.Engine [insertmanyvalues 39/638 (ordered; batch not supported)] ('apple', 'Apple iPhone 15 Pro Max', 937090, 7.9, 1, 'bionic', nan, nan, 4352.0, 1, 25.0, 8, 256, 6.68, 120, 3, 'ios', 50.0, 12.0, 0, 2778, 1284)
# 2025-01-15 22:46:06,405 INFO sqlalchemy.engine.Engine INSERT INTO smartphone (brand_name, model, price, avg_rating, "is_5G", processor_brand, num_cores, processor_speed, battery_capacity, fast_charging_available, fast_charging, ram_capacity, internal_memory, screen_size, refresh_rate, num_rear_cameras, os, primary_camera_rear, primary_camera_front, extended_memory_available, resolution_height, resolution_width) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 22:46:06,405 INFO sqlalchemy.engine.Engine [insertmanyvalues 40/638 (ordered; batch not supported)] ('apple', 'Apple iPhone 15 Ultra', 982370, 7.9, 1, 'bionic', 8.0, nan, 4700.0, 1, nan, 8, 128, 6.73, 120, 3, 'ios', 48.0, 12.0, 0, 2796, 1290)
# 2025-01-15 22:46:06,417 INFO sqlalchemy.engine.Engine INSERT INTO smartphone (brand_name, model, price, avg_rating, "is_5G", processor_brand, num_cores, processor_speed, battery_capacity, fast_charging_available, fast_charging, ram_capacity, internal_memory, screen_size, refresh_rate, num_rear_cameras, os, primary_camera_rear, primary_camera_front, extended_memory_available, resolution_height, resolution_width) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 22:46:06,420 INFO sqlalchemy.engine.Engine [insertmanyvalues 41/638 (ordered; batch not supported)] ('apple', 'Apple iPhone 7s', 347260, nan, 0, 'fusion', 4.0, 2.37, 2230.0, 0, nan, 3, 32, 4.7, 60, 1, 'ios', 13.0, 7.0, 0, 1334, 750)
# 2025-01-15 22:46:06,422 INFO sqlalchemy.engine.Engine INSERT INTO smartphone (brand_name, model, price, avg_rating, "is_5G", processor_brand, num_cores, processor_speed, battery_capacity, fast_charging_available, fast_charging, ram_capacity, internal_memory, screen_size, refresh_rate, num_rear_cameras, os, primary_camera_rear, primary_camera_front, extended_memory_available, resolution_height, resolution_width) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 22:46:06,424 INFO sqlalchemy.engine.Engine [insertmanyvalues 42/638 (ordered; batch not supported)] ('apple', 'Apple iPhone 9', 196530, 6.1, 0, 'bionic', 6.0, 2.65, 2050.0, 1, nan, 3, 64, 4.7, 60, 1, 'ios', 12.0, 7.0, 0, 1334, 750)
# 2025-01-15 22:46:06,425 INFO sqlalchemy.engine.Engine INSERT INTO smartphone (brand_name, model, price, avg_rating, "is_5G", processor_brand, num_cores, processor_speed, battery_capacity, fast_charging_available, fast_charging, ram_capacity, internal_memory, screen_size, refresh_rate, num_rear_cameras, os, primary_camera_rear, primary_camera_front, extended_memory_available, resolution_height, resolution_width) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 22:46:06,428 INFO sqlalchemy.engine.Engine [insertmanyvalues 43/638 (ordered; batch not supported)] ('apple', 'Apple iPhone SE 2020', 261470, 6.3, 0, 'bionic', 6.0, 2.65, 1821.0, 1, 18.0, 3, 64, 4.7, 60, 1, 'ios', 12.0, 7.0, 0, 1334, 750)
# 2025-01-15 22:46:06,430 INFO sqlalchemy.engine.Engine INSERT INTO smartphone (brand_name, model, price, avg_rating, "is_5G", processor_brand, num_cores, processor_speed, battery_capacity, fast_charging_available, fast_charging, ram_capacity, internal_memory, screen_size, refresh_rate, num_rear_cameras, os, primary_camera_rear, primary_camera_front, extended_memory_available, resolution_height, resolution_width) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 22:46:06,447 INFO sqlalchemy.engine.Engine [insertmanyvalues 44/638 (ordered; batch not supported)] ('apple', 'Apple iPhone SE 3 2022', 287700, nan, 1, 'bionic', 6.0, 3.22, nan, 0, nan, 4, 64, 4.7, 60, 1, 'ios', 12.0, 7.0, 0, 1334, 750)
# 2025-01-15 22:46:06,452 INFO sqlalchemy.engine.Engine INSERT INTO smartphone (brand_name, model, price, avg_rating, "is_5G", processor_brand, num_cores, processor_speed, battery_capacity, fast_charging_available, fast_charging, ram_capacity, internal_memory, screen_size, refresh_rate, num_rear_cameras, os, primary_camera_rear, primary_camera_front, extended_memory_available, resolution_height, resolution_width) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 22:46:06,455 INFO sqlalchemy.engine.Engine [insertmanyvalues 45/638 (ordered; batch not supported)] ('apple', 'Apple iPhone SE 4', 327600, 6.0, 1, 'bionic', 6.0, 3.22, nan, 0, nan, 4, 64, 6.1, 60, 1, 'ios', 12.0, 11.0, 0, 1580, 750)
# 2025-01-15 22:46:06,457 INFO sqlalchemy.engine.Engine INSERT INTO smartphone (brand_name, model, price, avg_rating, "is_5G", processor_brand, num_cores, processor_speed, battery_capacity, fast_charging_available, fast_charging, ram_capacity, internal_memory, screen_size, refresh_rate, num_rear_cameras, os, primary_camera_rear, primary_camera_front, extended_memory_available, resolution_height, resolution_width) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 22:46:06,460 INFO sqlalchemy.engine.Engine [insertmanyvalues 46/638 (ordered; batch not supported)] ('apple', 'Apple iPhone XR2', 471860, 6.0, 0, 'bionic', nan, nan, 3060.0, 1, nan, 4, 64, 6.1, 60, 2, 'ios', 12.0, 7.0, 0, 1792, 828)
# 2025-01-15 22:46:06,462 INFO sqlalchemy.engine.Engine INSERT INTO smartphone (brand_name, model, price, avg_rating, "is_5G", processor_brand, num_cores, processor_speed, battery_capacity, fast_charging_available, fast_charging, ram_capacity, internal_memory, screen_size, refresh_rate, num_rear_cameras, os, primary_camera_rear, primary_camera_front, extended_memory_available, resolution_height, resolution_width) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 22:46:06,463 INFO sqlalchemy.engine.Engine [insertmanyvalues 47/638 (ordered; batch not supported)] ('gionee', 'Gionee G13 Pro', 40580, nan, 0, 'tiger', 4.0, 2.0, 3500.0, 0, nan, 4, 32, 6.26, 60, 2, 'other', 13.0, 5.0, 1, 1600, 720)
# 2025-01-15 22:46:06,465 INFO sqlalchemy.engine.Engine INSERT INTO smartphone (brand_name, model, price, avg_rating, "is_5G", processor_brand, num_cores, processor_speed, battery_capacity, fast_charging_available, fast_charging, ram_capacity, internal_memory, screen_size, refresh_rate, num_rear_cameras, os, primary_camera_rear, primary_camera_front, extended_memory_available, resolution_height, resolution_width) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 22:46:06,467 INFO sqlalchemy.engine.Engine [insertmanyvalues 48/638 (ordered; batch not supported)] ('gionee', 'Gionee K10', 45870, nan, 0, 'tiger', 4.0, 2.0, 4800.0, 0, nan, 3, 32, 6.8, 60, 1, 'android', 13.0, 5.0, 1, 1600, 720)
# 2025-01-15 22:46:06,468 INFO sqlalchemy.engine.Engine INSERT INTO smartphone (brand_name, model, price, avg_rating, "is_5G", processor_brand, num_cores, processor_speed, battery_capacity, fast_charging_available, fast_charging, ram_capacity, internal_memory, screen_size, refresh_rate, num_rear_cameras, os, primary_camera_rear, primary_camera_front, extended_memory_available, resolution_height, resolution_width) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 22:46:06,470 INFO sqlalchemy.engine.Engine [insertmanyvalues 49/638 (ordered; batch not supported)] ('gionee', 'Gionee M12 Pro', 49150, 6.7, 0, 'helio', 8.0, 1.99, 4000.0, 0, nan, 6, 128, 6.2, 60, 1, 'android', 16.0, 13.0, 1, 1520, 720)
# 2025-01-15 22:46:06,474 INFO sqlalchemy.engine.Engine INSERT INTO smartphone (brand_name, model, price, avg_rating, "is_5G", processor_brand, num_cores, processor_speed, battery_capacity, fast_charging_available, fast_charging, ram_capacity, internal_memory, screen_size, refresh_rate, num_rear_cameras, os, primary_camera_rear, primary_camera_front, extended_memory_available, resolution_height, resolution_width) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 22:46:06,475 INFO sqlalchemy.engine.Engine [insertmanyvalues 50/638 (ordered; batch not supported)] ('honor', 'Honor 50', 216190, 8.5, 1, 'snapdragon', 8.0, 2.4, 4300.0, 1, 66.0, 6, 128, 6.57, 120, 4, 'android', 108.0, 32.0, 0, 2340, 1080)
# 2025-01-15 22:46:06,477 INFO sqlalchemy.engine.Engine INSERT INTO smartphone (brand_name, model, price, avg_rating, "is_5G", processor_brand, num_cores, processor_speed, battery_capacity, fast_charging_available, fast_charging, ram_capacity, internal_memory, screen_size, refresh_rate, num_rear_cameras, os, primary_camera_rear, primary_camera_front, extended_memory_available, resolution_height, resolution_width) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 22:46:06,478 INFO sqlalchemy.engine.Engine [insertmanyvalues 51/638 (ordered; batch not supported)] ('honor', 'Honor 60 SE 5G', 163760, 7.5, 1, 'dimensity', 8.0, 2.0, 4300.0, 1, 66.0, 8, 128, 6.67, 120, 3, 'android', 64.0, 16.0, 0, 2340, 1080)
# 2025-01-15 22:46:06,481 INFO sqlalchemy.engine.Engine INSERT INTO smartphone (brand_name, model, price, avg_rating, "is_5G", processor_brand, num_cores, processor_speed, battery_capacity, fast_charging_available, fast_charging, ram_capacity, internal_memory, screen_size, refresh_rate, num_rear_cameras, os, primary_camera_rear, primary_camera_front, extended_memory_available, resolution_height, resolution_width) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 22:46:06,483 INFO sqlalchemy.engine.Engine [insertmanyvalues 52/638 (ordered; batch not supported)] ('honor', 'Honor 70 5G', 262060, 8.8, 1, 'snapdragon', 8.0, 2.5, 4800.0, 1, 66.0, 12, 512, 6.67, 120, 3, 'android', 54.0, 32.0, 0, 2400, 1080)
# 2025-01-15 22:46:06,486 INFO sqlalchemy.engine.Engine INSERT INTO smartphone (brand_name, model, price, avg_rating, "is_5G", processor_brand, num_cores, processor_speed, battery_capacity, fast_charging_available, fast_charging, ram_capacity, internal_memory, screen_size, refresh_rate, num_rear_cameras, os, primary_camera_rear, primary_camera_front, extended_memory_available, resolution_height, resolution_width) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 22:46:06,488 INFO sqlalchemy.engine.Engine [insertmanyvalues 53/638 (ordered; batch not supported)] ('honor', 'Honor 70 5G (8GB RAM + 256GB)', 203090, 8.6, 1, 'snapdragon', 8.0, 2.5, 4800.0, 1, 66.0, 8, 256, 6.67, 120, 3, 'android', 54.0, 32.0, 0, 2400, 1080)
# 2025-01-15 22:46:06,490 INFO sqlalchemy.engine.Engine INSERT INTO smartphone (brand_name, model, price, avg_rating, "is_5G", processor_brand, num_cores, processor_speed, battery_capacity, fast_charging_available, fast_charging, ram_capacity, internal_memory, screen_size, refresh_rate, num_rear_cameras, os, primary_camera_rear, primary_camera_front, extended_memory_available, resolution_height, resolution_width) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 22:46:06,492 INFO sqlalchemy.engine.Engine [insertmanyvalues 54/638 (ordered; batch not supported)] ('honor', 'Honor 80 Pro Plus', 360370, nan, 1, 'snapdragon', 8.0, 3.0, 4500.0, 1, 100.0, 12, 256, 6.78, 120, 3, 'android', 200.0, 50.0, 0, 2652, 1200)
# 2025-01-15 22:46:06,493 INFO sqlalchemy.engine.Engine INSERT INTO smartphone (brand_name, model, price, avg_rating, "is_5G", processor_brand, num_cores, processor_speed, battery_capacity, fast_charging_available, fast_charging, ram_capacity, internal_memory, screen_size, refresh_rate, num_rear_cameras, os, primary_camera_rear, primary_camera_front, extended_memory_available, resolution_height, resolution_width) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 22:46:06,495 INFO sqlalchemy.engine.Engine [insertmanyvalues 55/638 (ordered; batch not supported)] ('honor', 'Honor Magic 4 Pro Plus 5G', 622510, nan, 1, 'snapdragon', 8.0, 3.0, 4600.0, 1, 120.0, 12, 512, 6.76, 120, 4, 'android', 50.0, 13.0, 0, 2772, 1344)
# 2025-01-15 22:46:06,497 INFO sqlalchemy.engine.Engine INSERT INTO smartphone (brand_name, model, price, avg_rating, "is_5G", processor_brand, num_cores, processor_speed, battery_capacity, fast_charging_available, fast_charging, ram_capacity, internal_memory, screen_size, refresh_rate, num_rear_cameras, os, primary_camera_rear, primary_camera_front, extended_memory_available, resolution_height, resolution_width) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 22:46:06,498 INFO sqlalchemy.engine.Engine [insertmanyvalues 56/638 (ordered; batch not supported)] ('honor', 'Honor Play 30', 65540, 6.8, 1, 'snapdragon', 8.0, 2.2, 5000.0, 0, nan, 4, 128, 6.5, 60, 1, 'android', 13.0, 5.0, 1, 1600, 720)
# 2025-01-15 22:46:06,500 INFO sqlalchemy.engine.Engine INSERT INTO smartphone (brand_name, model, price, avg_rating, "is_5G", processor_brand, num_cores, processor_speed, battery_capacity, fast_charging_available, fast_charging, ram_capacity, internal_memory, screen_size, refresh_rate, num_rear_cameras, os, primary_camera_rear, primary_camera_front, extended_memory_available, resolution_height, resolution_width) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 22:46:06,501 INFO sqlalchemy.engine.Engine [insertmanyvalues 57/638 (ordered; batch not supported)] ('honor', 'Honor X6', 91740, 7.1, 0, 'helio', 8.0, 2.0, 5000.0, 1, 10.0, 4, 64, 6.5, 60, 3, 'android', 50.0, 5.0, 1, 1600, 720)
# 2025-01-15 22:46:06,503 INFO sqlalchemy.engine.Engine INSERT INTO smartphone (brand_name, model, price, avg_rating, "is_5G", processor_brand, num_cores, processor_speed, battery_capacity, fast_charging_available, fast_charging, ram_capacity, internal_memory, screen_size, refresh_rate, num_rear_cameras, os, primary_camera_rear, primary_camera_front, extended_memory_available, resolution_height, resolution_width) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 22:46:06,504 INFO sqlalchemy.engine.Engine [insertmanyvalues 58/638 (ordered; batch not supported)] ('honor', 'Honor X7a', 91740, 7.5, 0, 'helio', 8.0, 2.3, 5000.0, 1, 22.0, 6, 128, 6.75, 90, 4, 'android', 50.0, 8.0, 1, 1600, 720)
# 2025-01-15 22:46:06,507 INFO sqlalchemy.engine.Engine INSERT INTO smartphone (brand_name, model, price, avg_rating, "is_5G", processor_brand, num_cores, processor_speed, battery_capacity, fast_charging_available, fast_charging, ram_capacity, internal_memory, screen_size, refresh_rate, num_rear_cameras, os, primary_camera_rear, primary_camera_front, extended_memory_available, resolution_height, resolution_width) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 22:46:06,510 INFO sqlalchemy.engine.Engine [insertmanyvalues 59/638 (ordered; batch not supported)] ('honor', 'Honor X8', 111410, 7.6, 0, 'snapdragon', 8.0, 2.4, 4000.0, 1, 22.0, 6, 128, 6.7, 90, 4, 'android', 64.0, 16.0, 0, 2388, 1080)
# 2025-01-15 22:46:06,511 INFO sqlalchemy.engine.Engine INSERT INTO smartphone (brand_name, model, price, avg_rating, "is_5G", processor_brand, num_cores, processor_speed, battery_capacity, fast_charging_available, fast_charging, ram_capacity, internal_memory, screen_size, refresh_rate, num_rear_cameras, os, primary_camera_rear, primary_camera_front, extended_memory_available, resolution_height, resolution_width) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 22:46:06,514 INFO sqlalchemy.engine.Engine [insertmanyvalues 60/638 (ordered; batch not supported)] ('honor', 'Honor X8 5G', 98220, 7.5, 1, 'snapdragon', 8.0, 2.2, 5000.0, 1, 22.0, 6, 128, 6.5, 60, 3, 'android', 48.0, 8.0, 1, 1600, 720)
# 2025-01-15 22:46:06,516 INFO sqlalchemy.engine.Engine INSERT INTO smartphone (brand_name, model, price, avg_rating, "is_5G", processor_brand, num_cores, processor_speed, battery_capacity, fast_charging_available, fast_charging, ram_capacity, internal_memory, screen_size, refresh_rate, num_rear_cameras, os, primary_camera_rear, primary_camera_front, extended_memory_available, resolution_height, resolution_width) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 22:46:06,518 INFO sqlalchemy.engine.Engine [insertmanyvalues 61/638 (ordered; batch not supported)] ('honor', 'Honor X9 5G', 111410, 8.0, 1, 'snapdragon', 8.0, 2.2, 4800.0, 1, 66.0, 8, 128, 6.81, 60, 3, 'android', 48.0, 16.0, 0, 2388, 1080)
# 2025-01-15 22:46:06,521 INFO sqlalchemy.engine.Engine INSERT INTO smartphone (brand_name, model, price, avg_rating, "is_5G", processor_brand, num_cores, processor_speed, battery_capacity, fast_charging_available, fast_charging, ram_capacity, internal_memory, screen_size, refresh_rate, num_rear_cameras, os, primary_camera_rear, primary_camera_front, extended_memory_available, resolution_height, resolution_width) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 22:46:06,522 INFO sqlalchemy.engine.Engine [insertmanyvalues 62/638 (ordered; batch not supported)] ('honor', 'Honor X9a', 183500, 8.1, 1, 'snapdragon', 8.0, 2.2, 5100.0, 1, 40.0, 8, 256, 6.67, 120, 3, 'android', 64.0, 16.0, 0, 2400, 1080)
# 2025-01-15 22:46:06,525 INFO sqlalchemy.engine.Engine INSERT INTO smartphone (brand_name, model, price, avg_rating, "is_5G", processor_brand, num_cores, processor_speed, battery_capacity, fast_charging_available, fast_charging, ram_capacity, internal_memory, screen_size, refresh_rate, num_rear_cameras, os, primary_camera_rear, primary_camera_front, extended_memory_available, resolution_height, resolution_width) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 22:46:06,526 INFO sqlalchemy.engine.Engine [insertmanyvalues 63/638 (ordered; batch not supported)] ('huawei', 'Huawei Honor 9N', 71760, 6.6, 0, 'kirin', 8.0, 2.36, 3000.0, 0, nan, 4, 64, 5.84, 60, 2, 'android', 13.0, 16.0, 1, 2280, 1080)
# ...
# 2025-01-15 22:46:09,070 INFO sqlalchemy.engine.Engine [insertmanyvalues 618/638 (ordered; batch not supported)] ('xiaomi', 'Xiaomi Redmi Note 12 Discovery Edition', 176860, 8.6, 1, 'dimensity', 8.0, 2.6, 4300.0, 1, 210.0, 8, 256, 6.67, 120, 3, 'android', 200.0, 16.0, 0, 2400, 1080)
# 2025-01-15 22:46:09,072 INFO sqlalchemy.engine.Engine INSERT INTO smartphone (brand_name, model, price, avg_rating, "is_5G", processor_brand, num_cores, processor_speed, battery_capacity, fast_charging_available, fast_charging, ram_capacity, internal_memory, screen_size, refresh_rate, num_rear_cameras, os, primary_camera_rear, primary_camera_front, extended_memory_available, resolution_height, resolution_width) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 22:46:09,074 INFO sqlalchemy.engine.Engine [insertmanyvalues 619/638 (ordered; batch not supported)] ('xiaomi', 'Xiaomi Redmi Note 12 Explorer', 163840, 8.9, 1, 'dimensity', 8.0, 2.6, 4300.0, 1, 120.0, 8, 256, 6.67, 120, 3, 'android', 200.0, 16.0, 1, 2400, 1080)
# 2025-01-15 22:46:09,076 INFO sqlalchemy.engine.Engine INSERT INTO smartphone (brand_name, model, price, avg_rating, "is_5G", processor_brand, num_cores, processor_speed, battery_capacity, fast_charging_available, fast_charging, ram_capacity, internal_memory, screen_size, refresh_rate, num_rear_cameras, os, primary_camera_rear, primary_camera_front, extended_memory_available, resolution_height, resolution_width) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 22:46:09,078 INFO sqlalchemy.engine.Engine [insertmanyvalues 620/638 (ordered; batch not supported)] ('xiaomi', 'Xiaomi Redmi Note 12 Pro (8GB RAM + 128GB)', 176940, 8.2, 1, 'dimensity', 8.0, 2.6, 5000.0, 1, 67.0, 8, 128, 6.67, 120, 3, 'android', 50.0, 16.0, 0, 2400, 1080)
# 2025-01-15 22:46:09,081 INFO sqlalchemy.engine.Engine INSERT INTO smartphone (brand_name, model, price, avg_rating, "is_5G", processor_brand, num_cores, processor_speed, battery_capacity, fast_charging_available, fast_charging, ram_capacity, internal_memory, screen_size, refresh_rate, num_rear_cameras, os, primary_camera_rear, primary_camera_front, extended_memory_available, resolution_height, resolution_width) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 22:46:09,084 INFO sqlalchemy.engine.Engine [insertmanyvalues 621/638 (ordered; batch not supported)] ('xiaomi', 'Xiaomi Redmi Note 12 Pro (8GB RAM + 256GB)', 183460, 8.2, 1, 'dimensity', 8.0, 2.6, 5000.0, 1, 67.0, 8, 256, 6.67, 120, 3, 'android', 50.0, 16.0, 0, 2400, 1080)
# 2025-01-15 22:46:09,086 INFO sqlalchemy.engine.Engine INSERT INTO smartphone (brand_name, model, price, avg_rating, "is_5G", processor_brand, num_cores, processor_speed, battery_capacity, fast_charging_available, fast_charging, ram_capacity, internal_memory, screen_size, refresh_rate, num_rear_cameras, os, primary_camera_rear, primary_camera_front, extended_memory_available, resolution_height, resolution_width) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 22:46:09,087 INFO sqlalchemy.engine.Engine [insertmanyvalues 622/638 (ordered; batch not supported)] ('xiaomi', 'Xiaomi Redmi Note 12 Pro 4G', 98300, 7.7, 0, 'snapdragon', 8.0, 2.3, 5000.0, 1, 67.0, 6, 128, 6.67, 120, 3, 'android', 50.0, 16.0, 0, 2400, 1080)
# 2025-01-15 22:46:09,088 INFO sqlalchemy.engine.Engine INSERT INTO smartphone (brand_name, model, price, avg_rating, "is_5G", processor_brand, num_cores, processor_speed, battery_capacity, fast_charging_available, fast_charging, ram_capacity, internal_memory, screen_size, refresh_rate, num_rear_cameras, os, primary_camera_rear, primary_camera_front, extended_memory_available, resolution_height, resolution_width) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 22:46:09,091 INFO sqlalchemy.engine.Engine [insertmanyvalues 623/638 (ordered; batch not supported)] ('xiaomi', 'Xiaomi Redmi Note 12 Pro 5G', 162270, 7.9, 1, 'dimensity', 8.0, 2.6, 5000.0, 1, 67.0, 6, 128, 6.67, 120, 3, 'android', 50.0, 16.0, 0, 2400, 1080)
# 2025-01-15 22:46:09,094 INFO sqlalchemy.engine.Engine INSERT INTO smartphone (brand_name, model, price, avg_rating, "is_5G", processor_brand, num_cores, processor_speed, battery_capacity, fast_charging_available, fast_charging, ram_capacity, internal_memory, screen_size, refresh_rate, num_rear_cameras, os, primary_camera_rear, primary_camera_front, extended_memory_available, resolution_height, resolution_width) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 22:46:09,096 INFO sqlalchemy.engine.Engine [insertmanyvalues 624/638 (ordered; batch not supported)] ('xiaomi', 'Xiaomi Redmi Note 12 Pro Max 5G', 216270, 8.3, 1, 'snapdragon', 8.0, 2.36, 5200.0, 1, 210.0, 6, 128, 6.67, 120, 4, 'android', 108.0, 32.0, 1, 2460, 1080)
# 2025-01-15 22:46:09,101 INFO sqlalchemy.engine.Engine INSERT INTO smartphone (brand_name, model, price, avg_rating, "is_5G", processor_brand, num_cores, processor_speed, battery_capacity, fast_charging_available, fast_charging, ram_capacity, internal_memory, screen_size, refresh_rate, num_rear_cameras, os, primary_camera_rear, primary_camera_front, extended_memory_available, resolution_height, resolution_width) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 22:46:09,103 INFO sqlalchemy.engine.Engine [insertmanyvalues 625/638 (ordered; batch not supported)] ('xiaomi', 'Xiaomi Redmi Note 12 Pro Plus', 196610, 8.6, 1, 'dimensity', 8.0, 2.6, 4980.0, 1, 120.0, 8, 256, 6.67, 120, 3, 'android', 200.0, 16.0, 0, 2400, 1080)
# 2025-01-15 22:46:09,105 INFO sqlalchemy.engine.Engine INSERT INTO smartphone (brand_name, model, price, avg_rating, "is_5G", processor_brand, num_cores, processor_speed, battery_capacity, fast_charging_available, fast_charging, ram_capacity, internal_memory, screen_size, refresh_rate, num_rear_cameras, os, primary_camera_rear, primary_camera_front, extended_memory_available, resolution_height, resolution_width) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 22:46:09,106 INFO sqlalchemy.engine.Engine [insertmanyvalues 626/638 (ordered; batch not supported)] ('xiaomi', 'Xiaomi Redmi Note 12 Pro Plus (12GB RAM + 256GB)', 216270, 8.7, 1, 'dimensity', 8.0, 2.6, 4980.0, 1, 120.0, 12, 256, 6.67, 120, 3, 'android', 200.0, 16.0, 0, 2400, 1080)
# 2025-01-15 22:46:09,108 INFO sqlalchemy.engine.Engine INSERT INTO smartphone (brand_name, model, price, avg_rating, "is_5G", processor_brand, num_cores, processor_speed, battery_capacity, fast_charging_available, fast_charging, ram_capacity, internal_memory, screen_size, refresh_rate, num_rear_cameras, os, primary_camera_rear, primary_camera_front, extended_memory_available, resolution_height, resolution_width) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 22:46:09,110 INFO sqlalchemy.engine.Engine [insertmanyvalues 627/638 (ordered; batch not supported)] ('xiaomi', 'Xiaomi Redmi Note 12 Pro Plus (6GB RAM + 128GB)', 176940, 8.4, 1, 'dimensity', 8.0, 2.6, 4980.0, 1, 120.0, 6, 128, 6.67, 120, 3, 'android', 200.0, 16.0, 0, 2400, 1080)
# 2025-01-15 22:46:09,112 INFO sqlalchemy.engine.Engine INSERT INTO smartphone (brand_name, model, price, avg_rating, "is_5G", processor_brand, num_cores, processor_speed, battery_capacity, fast_charging_available, fast_charging, ram_capacity, internal_memory, screen_size, refresh_rate, num_rear_cameras, os, primary_camera_rear, primary_camera_front, extended_memory_available, resolution_height, resolution_width) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 22:46:09,113 INFO sqlalchemy.engine.Engine [insertmanyvalues 628/638 (ordered; batch not supported)] ('xiaomi', 'Xiaomi Redmi Note 12 Turbo', 131070, 8.1, 1, 'snapdragon', 8.0, 2.4, 5000.0, 1, 67.0, 8, 128, 6.67, 120, 3, 'android', 50.0, 16.0, 0, 2400, 1080)
# 2025-01-15 22:46:09,114 INFO sqlalchemy.engine.Engine INSERT INTO smartphone (brand_name, model, price, avg_rating, "is_5G", processor_brand, num_cores, processor_speed, battery_capacity, fast_charging_available, fast_charging, ram_capacity, internal_memory, screen_size, refresh_rate, num_rear_cameras, os, primary_camera_rear, primary_camera_front, extended_memory_available, resolution_height, resolution_width) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 22:46:09,118 INFO sqlalchemy.engine.Engine [insertmanyvalues 629/638 (ordered; batch not supported)] ('xiaomi', 'Xiaomi Redmi Note 12T 5G', 104860, 7.8, 1, 'dimensity', 8.0, 2.0, 5000.0, 1, 33.0, 6, 64, 6.52, 90, 3, 'android', 64.0, 16.0, 1, 2400, 1080)
# 2025-01-15 22:46:09,120 INFO sqlalchemy.engine.Engine INSERT INTO smartphone (brand_name, model, price, avg_rating, "is_5G", processor_brand, num_cores, processor_speed, battery_capacity, fast_charging_available, fast_charging, ram_capacity, internal_memory, screen_size, refresh_rate, num_rear_cameras, os, primary_camera_rear, primary_camera_front, extended_memory_available, resolution_height, resolution_width) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 22:46:09,121 INFO sqlalchemy.engine.Engine [insertmanyvalues 630/638 (ordered; batch not supported)] ('xiaomi', 'Xiaomi Redmi Note 13 Pro 5G', 117890, 7.8, 1, 'dimensity', 8.0, 2.0, 5000.0, 1, 67.0, 6, 128, 6.67, 120, 3, 'android', 108.0, 16.0, 0, 2460, 1080)
# 2025-01-15 22:46:09,124 INFO sqlalchemy.engine.Engine INSERT INTO smartphone (brand_name, model, price, avg_rating, "is_5G", processor_brand, num_cores, processor_speed, battery_capacity, fast_charging_available, fast_charging, ram_capacity, internal_memory, screen_size, refresh_rate, num_rear_cameras, os, primary_camera_rear, primary_camera_front, extended_memory_available, resolution_height, resolution_width) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 22:46:09,126 INFO sqlalchemy.engine.Engine [insertmanyvalues 631/638 (ordered; batch not supported)] ('xiaomi', 'Xiaomi Redmi Note 13 Pro Max 5G', 134350, 8.3, 1, 'snapdragon', 8.0, 2.36, 5200.0, 1, 67.0, 6, 128, 6.67, 120, 4, 'android', 108.0, 32.0, 1, 2460, 1080)
# 2025-01-15 22:46:09,128 INFO sqlalchemy.engine.Engine INSERT INTO smartphone (brand_name, model, price, avg_rating, "is_5G", processor_brand, num_cores, processor_speed, battery_capacity, fast_charging_available, fast_charging, ram_capacity, internal_memory, screen_size, refresh_rate, num_rear_cameras, os, primary_camera_rear, primary_camera_front, extended_memory_available, resolution_height, resolution_width) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 22:46:09,129 INFO sqlalchemy.engine.Engine [insertmanyvalues 632/638 (ordered; batch not supported)] ('xiaomi', 'Xiaomi Redmi Note 4', 67500, 6.5, 0, 'snapdragon', 8.0, 2.0, 4100.0, 0, nan, 4, 64, 5.5, 60, 1, 'android', 13.0, 5.0, 1, 1920, 1080)
# 2025-01-15 22:46:09,131 INFO sqlalchemy.engine.Engine INSERT INTO smartphone (brand_name, model, price, avg_rating, "is_5G", processor_brand, num_cores, processor_speed, battery_capacity, fast_charging_available, fast_charging, ram_capacity, internal_memory, screen_size, refresh_rate, num_rear_cameras, os, primary_camera_rear, primary_camera_front, extended_memory_available, resolution_height, resolution_width) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 22:46:09,133 INFO sqlalchemy.engine.Engine [insertmanyvalues 633/638 (ordered; batch not supported)] ('xiaomi', 'Xiaomi Redmi Note 8 2021', 65460, 7.5, 0, 'helio', 8.0, 2.0, 4000.0, 1, 18.0, 4, 64, 6.3, 60, 4, 'android', 48.0, 13.0, 1, 2340, 1080)
# 2025-01-15 22:46:09,136 INFO sqlalchemy.engine.Engine INSERT INTO smartphone (brand_name, model, price, avg_rating, "is_5G", processor_brand, num_cores, processor_speed, battery_capacity, fast_charging_available, fast_charging, ram_capacity, internal_memory, screen_size, refresh_rate, num_rear_cameras, os, primary_camera_rear, primary_camera_front, extended_memory_available, resolution_height, resolution_width) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 22:46:09,138 INFO sqlalchemy.engine.Engine [insertmanyvalues 634/638 (ordered; batch not supported)] ('xiaomi', 'Xiaomi Redmi Note 8 Pro', 111410, 7.8, 0, 'helio', 8.0, 2.05, 4500.0, 1, 18.0, 6, 64, 6.53, 60, 4, 'android', 64.0, 20.0, 1, 2340, 1080)
# 2025-01-15 22:46:09,139 INFO sqlalchemy.engine.Engine INSERT INTO smartphone (brand_name, model, price, avg_rating, "is_5G", processor_brand, num_cores, processor_speed, battery_capacity, fast_charging_available, fast_charging, ram_capacity, internal_memory, screen_size, refresh_rate, num_rear_cameras, os, primary_camera_rear, primary_camera_front, extended_memory_available, resolution_height, resolution_width) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 22:46:09,140 INFO sqlalchemy.engine.Engine [insertmanyvalues 635/638 (ordered; batch not supported)] ('xiaomi', 'Xiaomi Redmi Note 9', 78560, 7.5, 0, 'helio', 8.0, 2.0, 5020.0, 1, 22.0, 4, 64, 6.53, 60, 4, 'android', 48.0, 13.0, 1, 2340, 1080)
# 2025-01-15 22:46:09,142 INFO sqlalchemy.engine.Engine INSERT INTO smartphone (brand_name, model, price, avg_rating, "is_5G", processor_brand, num_cores, processor_speed, battery_capacity, fast_charging_available, fast_charging, ram_capacity, internal_memory, screen_size, refresh_rate, num_rear_cameras, os, primary_camera_rear, primary_camera_front, extended_memory_available, resolution_height, resolution_width) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 22:46:09,152 INFO sqlalchemy.engine.Engine [insertmanyvalues 636/638 (ordered; batch not supported)] ('xiaomi', 'Xiaomi Redmi Note 9 Pro', 91740, 7.5, 0, 'snapdragon', 8.0, 2.3, 5020.0, 1, 18.0, 4, 64, 6.67, 60, 4, 'android', 48.0, 16.0, 1, 2400, 1080)
# 2025-01-15 22:46:09,155 INFO sqlalchemy.engine.Engine INSERT INTO smartphone (brand_name, model, price, avg_rating, "is_5G", processor_brand, num_cores, processor_speed, battery_capacity, fast_charging_available, fast_charging, ram_capacity, internal_memory, screen_size, refresh_rate, num_rear_cameras, os, primary_camera_rear, primary_camera_front, extended_memory_available, resolution_height, resolution_width) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 22:46:09,157 INFO sqlalchemy.engine.Engine [insertmanyvalues 637/638 (ordered; batch not supported)] ('xiaomi', 'Xiaomi Redmi Note 9 Pro (4GB RAM + 128GB)', 94620, 7.7, 0, 'snapdragon', 8.0, 2.3, 5020.0, 1, 18.0, 4, 128, 6.67, 60, 4, 'android', 48.0, 16.0, 1, 2400, 1080)
# 2025-01-15 22:46:09,158 INFO sqlalchemy.engine.Engine INSERT INTO smartphone (brand_name, model, price, avg_rating, "is_5G", processor_brand, num_cores, processor_speed, battery_capacity, fast_charging_available, fast_charging, ram_capacity, internal_memory, screen_size, refresh_rate, num_rear_cameras, os, primary_camera_rear, primary_camera_front, extended_memory_available, resolution_height, resolution_width) VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 22:46:09,159 INFO sqlalchemy.engine.Engine [insertmanyvalues 638/638 (ordered; batch not supported)] ('xiaomi', 'Xiaomi Redmi Note 9 Pro Max', 108060, 8.0, 0, 'snapdragon', 8.0, 2.3, 5020.0, 1, 33.0, 6, 64, 6.67, 60, 4, 'android', 64.0, 32.0, 1, 2400, 1080)
# 2025-01-15 22:46:09,185 INFO sqlalchemy.engine.Engine COMMIT
# Data inserted successfully!

# %%
from sqlalchemy import create_engine
from sqlalchemy.orm import sessionmaker

engine = create_engine("sqlite:///products.db")  # Adjust path if needed
Session = sessionmaker(bind=engine)
session = Session()


try:
    smartphones = session.query(SmartPhone).all()
    
    # Step 3: Print each smartphone record
    for phone in smartphones:
        print(f"ID: {phone.id}, Brand: {phone.brand_name}, Model: {phone.model}, Price: {phone.price}, "
              f"Avg Rating: {phone.avg_rating}, Is 5G: {phone.is_5G}, Processor: {phone.processor_brand}, "
              f"RAM: {phone.ram_capacity}, Storage: {phone.internal_memory}")
except Exception as e:
    print("Error occurred while fetching data:", e)
finally:
    session.close()
# Out:
# ID: 1, Brand: apple, Model: Apple iPhone 11, Price: 255580, Avg Rating: 7.3, Is 5G: False, Processor: bionic, RAM: 4, Storage: 64
# ID: 2, Brand: apple, Model: Apple iPhone 11 (128GB), Price: 308020, Avg Rating: 7.5, Is 5G: False, Processor: bionic, RAM: 4, Storage: 128
# ID: 3, Brand: apple, Model: Apple iPhone 11 Pro Max, Price: 720220, Avg Rating: 7.7, Is 5G: False, Processor: bionic, RAM: 4, Storage: 64
# ID: 4, Brand: apple, Model: Apple iPhone 12, Price: 340780, Avg Rating: 7.4, Is 5G: True, Processor: bionic, RAM: 4, Storage: 64
# ID: 5, Brand: apple, Model: Apple iPhone 12 (128GB), Price: 367010, Avg Rating: 7.5, Is 5G: True, Processor: bionic, RAM: 4, Storage: 128
# ID: 6, Brand: apple, Model: Apple iPhone 12 (256GB), Price: 445650, Avg Rating: 7.6, Is 5G: True, Processor: bionic, RAM: 4, Storage: 256
# ID: 7, Brand: apple, Model: Apple iPhone 12 Mini, Price: 268700, Avg Rating: 7.4, Is 5G: True, Processor: bionic, RAM: 4, Storage: 64
# ID: 8, Brand: apple, Model: Apple iPhone 12 Mini (128GB), Price: 301470, Avg Rating: 7.5, Is 5G: True, Processor: bionic, RAM: 4, Storage: 128
# ID: 9, Brand: apple, Model: Apple iPhone 12 Mini (256GB), Price: 367010, Avg Rating: 7.5, Is 5G: True, Processor: bionic, RAM: 4, Storage: 256
# ID: 10, Brand: apple, Model: Apple iPhone 12 Pro (256GB), Price: 785760, Avg Rating: 8.0, Is 5G: True, Processor: bionic, RAM: 6, Storage: 256
# ID: 11, Brand: apple, Model: Apple iPhone 12 Pro (512GB), Price: 916830, Avg Rating: 8.0, Is 5G: True, Processor: bionic, RAM: 6, Storage: 512
# ID: 12, Brand: apple, Model: Apple iPhone 13, Price: 412880, Avg Rating: 7.9, Is 5G: True, Processor: bionic, RAM: 4, Storage: 128
# ID: 13, Brand: apple, Model: Apple iPhone 13 (256GB), Price: 478420, Avg Rating: 7.9, Is 5G: True, Processor: bionic, RAM: 4, Storage: 256
# ID: 14, Brand: apple, Model: Apple iPhone 13 (512GB), Price: 602930, Avg Rating: 8.0, Is 5G: True, Processor: bionic, RAM: 4, Storage: 512
# ID: 15, Brand: apple, Model: Apple iPhone 13 Mini, Price: 425310, Avg Rating: 7.9, Is 5G: True, Processor: bionic, RAM: 4, Storage: 128
# ID: 16, Brand: apple, Model: Apple iPhone 13 Pro, Price: 785760, Avg Rating: 8.3, Is 5G: True, Processor: bionic, RAM: 6, Storage: 128
# ID: 17, Brand: apple, Model: Apple iPhone 13 Pro (1TB), Price: 969260, Avg Rating: 8.4, Is 5G: True, Processor: bionic, RAM: 6, Storage: 1024
# ID: 18, Brand: apple, Model: Apple iPhone 13 Pro (256GB), Price: 851300, Avg Rating: 8.3, Is 5G: True, Processor: bionic, RAM: 6, Storage: 256
# ID: 19, Brand: apple, Model: Apple iPhone 13 Pro Max, Price: 851300, Avg Rating: 8.4, Is 5G: True, Processor: bionic, RAM: 6, Storage: 128
# ID: 20, Brand: apple, Model: Apple iPhone 13 Pro Max (1TB), Price: 1178980, Avg Rating: 8.6, Is 5G: True, Processor: bionic, RAM: 6, Storage: 1024
# ID: 21, Brand: apple, Model: Apple iPhone 13 Pro Max (256GB), Price: 916830, Avg Rating: 8.4, Is 5G: True, Processor: bionic, RAM: 6, Storage: 256
# ID: 22, Brand: apple, Model: Apple iPhone 14, Price: 432540, Avg Rating: 8.1, Is 5G: True, Processor: bionic, RAM: 6, Storage: 128
# ID: 23, Brand: apple, Model: Apple iPhone 14 (256GB), Price: 498080, Avg Rating: 8.2, Is 5G: True, Processor: bionic, RAM: 6, Storage: 256
# ID: 24, Brand: apple, Model: Apple iPhone 14 (512GB), Price: 629150, Avg Rating: 8.2, Is 5G: True, Processor: bionic, RAM: 6, Storage: 512
# ID: 25, Brand: apple, Model: Apple iPhone 14 Mini, Price: 458670, Avg Rating: 7.0, Is 5G: False, Processor: bionic, RAM: 6, Storage: 128
# ID: 26, Brand: apple, Model: Apple iPhone 14 Plus, Price: 491520, Avg Rating: 8.2, Is 5G: True, Processor: bionic, RAM: 6, Storage: 128
# ID: 27, Brand: apple, Model: Apple iPhone 14 Plus (256GB), Price: 557060, Avg Rating: 8.3, Is 5G: True, Processor: bionic, RAM: 6, Storage: 256
# ID: 28, Brand: apple, Model: Apple iPhone 14 Plus (512GB), Price: 688130, Avg Rating: 8.3, Is 5G: True, Processor: bionic, RAM: 6, Storage: 512
# ID: 29, Brand: apple, Model: Apple iPhone 14 Pro, Price: 786350, Avg Rating: 7.5, Is 5G: True, Processor: bionic, RAM: 6, Storage: 128
# ID: 30, Brand: apple, Model: Apple iPhone 14 Pro (1TB), Price: 1133780, Avg Rating: 7.7, Is 5G: True, Processor: bionic, RAM: 6, Storage: 1024
# ID: 31, Brand: apple, Model: Apple iPhone 14 Pro (256GB), Price: 851890, Avg Rating: 7.6, Is 5G: True, Processor: bionic, RAM: 6, Storage: 256
# ID: 32, Brand: apple, Model: Apple iPhone 14 Pro Max, Price: 851890, Avg Rating: 7.6, Is 5G: True, Processor: bionic, RAM: 6, Storage: 128
# ID: 33, Brand: apple, Model: Apple iPhone 14 Pro Max (1TB), Price: 1199310, Avg Rating: 7.8, Is 5G: True, Processor: bionic, RAM: 6, Storage: 1024
# ID: 34, Brand: apple, Model: Apple iPhone 14 Pro Max (256GB), Price: 917420, Avg Rating: 7.7, Is 5G: True, Processor: bionic, RAM: 6, Storage: 256
# ID: 35, Brand: apple, Model: Apple iPhone 14 Pro Max (512GB), Price: 1113440, Avg Rating: 7.8, Is 5G: True, Processor: bionic, RAM: 6, Storage: 512
# ID: 36, Brand: apple, Model: Apple iPhone 15, Price: 543870, Avg Rating: 7.2, Is 5G: False, Processor: bionic, RAM: 6, Storage: 128
# ID: 37, Brand: apple, Model: Apple iPhone 15 Plus, Price: 556980, Avg Rating: 7.5, Is 5G: True, Processor: bionic, RAM: 8, Storage: 128
# ID: 38, Brand: apple, Model: Apple iPhone 15 Pro, Price: 858450, Avg Rating: 7.5, Is 5G: True, Processor: bionic, RAM: 8, Storage: 128
Is 5G: True, Processor: snapdragon, RAM: 8, Storage: 256
# ID: 63, Brand: huawei, Model: Huawei Honor 9N, Price: 71760, Avg Rating: 6.6, Is 5G: False, Processor: kirin, RAM: 4, Storage: 64
# ID: 64, Brand: huawei, Model: Huawei Mate 30 RS Porsche Design, Price: 1408940, Avg Rating: None, Is 5G: True, Processor: kirin, RAM: 12, Storage: 512
# ID: 65, Brand: huawei, Model: Huawei Mate 40 Pro 4G, Price: 458670, Avg Rating: None, Is 5G: False, Processor: kirin, RAM: 8, Storage: 128
# ID: 66, Brand: huawei, Model: Huawei Mate 50 Pro 5G, Price: 655280, Avg Rating: 8.5, Is 5G: True, Processor: kirin, RAM: 8, Storage: 256
# ID: 67, Brand: huawei, Model: Huawei Mate 50 RS Porsche Design, Price: 1572860, Avg Rating: 8.1, Is 5G: False, Processor: snapdragon, RAM: 12, Storage: 512
# ID: 68, Brand: huawei, Model: Huawei Mate X, Price: 1107550, Avg Rating: None, Is 5G: True, Processor: kirin, RAM: 8, Storage: 512
# ID: 69, Brand: huawei, Model: Huawei Mate Xs 2, Price: 1068160, Avg Rating: 8.9, Is 5G: False, Processor: snapdragon, RAM: 8, Storage: 512
# ID: 70, Brand: huawei, Model: Huawei Nova 10, Price: 196530, Avg Rating: 8.2, Is 5G: False, Processor: snapdragon, RAM: 8, Storage: 128
# ID: 71, Brand: huawei, Model: Huawei Nova 10 SE, Price: 157280, Avg Rating: 8.4, Is 5G: False, Processor: snapdragon, RAM: 8, Storage: 256
# ID: 72, Brand: huawei, Model: Huawei Nova 7i, Price: 144100, Avg Rating: 8.1, Is 5G: False, Processor: kirin, RAM: 8, Storage: 128
# ID: 73, Brand: huawei, Model: Huawei Nova 9, Price: 196530, Avg Rating: 8.3, Is 5G: False, Processor: snapdragon, RAM: 8, Storage: 128
# ID: 74, Brand: huawei, Model: Huawei Nova 9 SE, Price: 130990, Avg Rating: 8.4, Is 5G: False, Processor: snapdragon, RAM: 8, Storage: 128
# ID: 75, Brand: huawei, Model: Huawei Nova Y61, Price: 144100, Avg Rating: 6.3, Is 5G: False, Processor: None, RAM: 4, Storage: 64
# ID: 76, Brand: huawei, Model: Huawei Nova Y90, Price: 150660, Avg Rating: 8.2, Is 5G: False, Processor: snapdragon, RAM: 8, Storage: 128
# ID: 77, Brand: huawei, Model: Huawei P40 Pro, Price: 543870, Avg Rating: None, Is 5G: True, Processor: kirin, RAM: 8, Storage: 256
# ID: 78, Brand: huawei, Model: Huawei P50 Pro 4G, Price: 399780, Avg Rating: None, Is 5G: False, Processor: snapdragon, RAM: 8, Storage: 256
# ID: 79, Brand: oneplus, Model: OnePlus 10 Pro 5G, Price: 399780, Avg Rating: 8.9, Is 5G: True, Processor: snapdragon, RAM: 8, Storage: 128
# ID: 80, Brand: oneplus, Model: OnePlus 10 Pro 5G (12GB RAM + 256GB), Price: 429260, Avg Rating: None, Is 5G: True, Processor: snapdragon, RAM: 12, Storage: 256
# ID: 81, Brand: oneplus, Model: OnePlus 10 Pro 5G (12GB RAM + 512GB), Price: 491520, Avg Rating: None, Is 5G: True, Processor: snapdragon, RAM: 12, Storage: 512
# ID: 82, Brand: oneplus, Model: OnePlus 10R 5G, Price: 216270, Avg Rating: 8.6, Is 5G: True, Processor: dimensity, RAM: 8, Storage: 128
# ID: 83, Brand: oneplus, Model: OnePlus 10R 5G (12GB RAM + 256GB), Price: 242480, Avg Rating: 8.7, Is 5G: True, Processor: dimensity, RAM: 12, Storage: 256
# ID: 84, Brand: oneplus, Model: OnePlus 10R Prime Edition, Price: 231940, Avg Rating: 8.5, Is 5G: True, Processor: dimensity, RAM: 8, Storage: 128
# ID: 85, Brand: oneplus, Model: OnePlus 10T, Price: 294910, Avg Rating: 8.5, Is 5G: True, Processor: snapdragon, RAM: 8, Storage: 128
# ID: 86, Brand: oneplus, Model: OnePlus 10T (12GB RAM + 256GB), Price: 334240, Avg Rating: 8.7, Is 5G: True, Processor: snapdragon, RAM: 12, Storage: 256
# ID: 87, Brand: oneplus, Model: OnePlus 10T (16GB RAM + 256GB), Price: 367010, Avg Rating: 8.7, Is 5G: True, Processor: snapdragon, RAM: 16, Storage: 256
# ID: 88, Brand: oneplus, Model: OnePlus 11 5G, Price: 360450, Avg Rating: 8.9, Is 5G: True, Processor: snapdragon, RAM: 12, Storage:
Processor: snapdragon, RAM: 4, Storage: 64
# ID: 118, Brand: oneplus, Model: OnePlus Nord N300, Price: 124450, Avg Rating: 7.5, Is 5G: True, Processor: dimensity, RAM: 4, Storage: 64
# ID: 119, Brand: oneplus, Model: OnePlus Nord SE, Price: 131070, Avg Rating: 7.3, Is 5G: False, Processor: snapdragon, RAM: 4, Storage: 64
# ID: 120, Brand: oneplus, Model: OnePlus Z, Price: 163840, Avg Rating: 7.9, Is 5G: False, Processor: snapdragon, RAM: 8, Storage: 128
# ID: 121, Brand: poco, Model: POCO C31, Price: 42590, Avg Rating: 6.5, Is 5G: False, Processor: helio, RAM: 3, Storage: 32
# ID: 122, Brand: poco, Model: POCO C31 (4GB RAM + 64GB), Price: 49150, Avg Rating: 6.8, Is 5G: False, Processor: helio, RAM: 4, Storage: 64
# ID: 123, Brand: poco, Model: Poco C50, Price: 42590, Avg Rating: None, Is 5G: False, Processor: helio, RAM: 2, Storage: 32
# ID: 124, Brand: poco, Model: Poco C50 (3GB RAM + 32GB), Price: 47840, Avg Rating: 6.1, Is 5G: False, Processor: helio, RAM: 3, Storage: 32
# ID: 125, Brand: poco, Model: Poco C55, Price: 52430, Avg Rating: 7.0, Is 5G: False, Processor: helio, RAM: 4, Storage: 64
# ID: 126, Brand: poco, Model: Poco F3 GT, Price: 216270, Avg Rating: 7.9, Is 5G: True, Processor: dimensity, RAM: 6, Storage: 128
# ID: 127, Brand: poco, Model: Poco F4 (12GB RAM + 256GB), Price: 196610, Avg Rating: 8.6, Is 5G: True, Processor: snapdragon, RAM: 12, Storage: 256
# ID: 128, Brand: poco, Model: Poco F4 5G, Price: 170400, Avg Rating: 8.2, Is 5G: True, Processor: snapdragon, RAM: 6, Storage: 128
# ID: 129, Brand: poco, Model: Poco F4 5G (8GB RAM + 128GB), Price: 183500, Avg Rating: 8.5, Is 5G: True, Processor: snapdragon, RAM: 8, Storage: 128
# ID: 130, Brand: poco, Model: POCO F4 GT 5G, Price: 262140, Avg Rating: 8.6, Is 5G: True, Processor: snapdragon, RAM: 8, Storage: 128
# ID: 131, Brand: poco, Model: Poco F5, Price: 229300, Avg Rating: 8.5, Is 5G: True, Processor: snapdragon, RAM: 8, Storage: 128
# ID: 132, Brand: poco, Model: POCO F5 GT 5G, Price: 281810, Avg Rating: 8.6, Is 5G: True, Processor: dimensity, RAM: 8, Storage: 128
# ID: 133, Brand: poco, Model: Poco F5 Pro, Price: 196610, Avg Rating: 8.4, Is 5G: True, Processor: snapdragon, RAM: 8, Storage: 128
# ID: 134, Brand: poco, Model: Poco M2, Price: 71380, Avg Rating: 7.4, Is 5G: False, Processor: helio, RAM: 6, Storage: 64
# ID: 135, Brand: poco, Model: POCO M2 Pro, Price: 83890, Avg Rating: 7.6, Is 5G: False, Processor: snapdragon, RAM: 4, Storage: 64
# ID: 136, Brand: poco, Model: Poco M3, Price: 75360, Avg Rating: 7.5, Is 5G: False, Processor: snapdragon, RAM: 6, Storage: 64
# ID: 137, Brand: poco, Model: POCO M3 Pro 5G, Price: 104860, Avg Rating: 7.5, Is 5G: True, Processor: dimensity, RAM: 4, Storage: 64
# ID: 138, Brand: poco, Model: POCO M3 Pro 5G (6GB RAM + 128GB), Price: 96990, Avg Rating: 7.9, Is 5G: True, Processor: dimensity, RAM: 6, Storage: 128
# ID: 139, Brand: poco, Model: Poco M4 5G, Price: 75360, Avg Rating: 7.5, Is 5G: True, Processor: dimensity, RAM: 4, Storage: 64
# ID: 140, Brand: poco, Model: Poco M4 5G (6GB RAM + 128GB), Price: 88480, Avg Rating: 7.9, Is 5G: True, Processor: dimensity, RAM: 6, Storage: 128
# ID: 141, Brand: poco, Model: POCO M4 Pro 4G, Price: 78640, Avg Rating: 7.7, Is 5G: False, Processor: helio, RAM: 6, Storage: 64
# ID: 142, Brand: poco, Model: POCO M4 Pro 4G (6GB RAM + 128GB), Price: 85200, Avg Rating: 7.9, Is 5G: False, Processor: helio, RAM: 6, Storage: 128
# ID: 143, Brand: poco, Model: POCO M4 Pro 4G (8GB RAM + 128GB), Price: 91740, Avg Rating: 8.1, Is 5G: False, Processor: helio, RAM: 8, Storage: 128
# ID: 144, Brand: poco, Model: Poco M4 Pro 5G, Price: 85200, Avg Rating: 7.6, Is 5G: True, Processor: dimensity, RAM: 4, Storage: 64
# ID: 145, Brand: poco, Model: Poco M4 Pro 5G (6GB RAM + 128GB), Price: 98300, Avg Rating: 8.1, Is 5G: True, Processor: dimensity, RAM: 6, Storage: 128
# ID:
Is 5G: True, Processor: dimensity, RAM: 6, Storage: 128
# ID: 624, Brand: xiaomi, Model: Xiaomi Redmi Note 12 Pro Max 5G, Price: 216270, Avg Rating: 8.3, Is 5G: True, Processor: snapdragon, RAM: 6, Storage: 128
# ID: 625, Brand: xiaomi, Model: Xiaomi Redmi Note 12 Pro Plus, Price: 196610, Avg Rating: 8.6, Is 5G: True, Processor: dimensity, RAM: 8, Storage: 256
# ID: 626, Brand: xiaomi, Model: Xiaomi Redmi Note 12 Pro Plus (12GB RAM + 256GB), Price: 216270, Avg Rating: 8.7, Is 5G: True, Processor: dimensity, RAM: 12, Storage: 256
# ID: 627, Brand: xiaomi, Model: Xiaomi Redmi Note 12 Pro Plus (6GB RAM + 128GB), Price: 176940, Avg Rating: 8.4, Is 5G: True, Processor: dimensity, RAM: 6, Storage: 128
# ID: 628, Brand: xiaomi, Model: Xiaomi Redmi Note 12 Turbo, Price: 131070, Avg Rating: 8.1, Is 5G: True, Processor: snapdragon, RAM: 8, Storage: 128
# ID: 629, Brand: xiaomi, Model: Xiaomi Redmi Note 12T 5G, Price: 104860, Avg Rating: 7.8, Is 5G: True, Processor: dimensity, RAM: 6, Storage: 64
# ID: 630, Brand: xiaomi, Model: Xiaomi Redmi Note 13 Pro 5G, Price: 117890, Avg Rating: 7.8, Is 5G: True, Processor: dimensity, RAM: 6, Storage: 128
# ID: 631, Brand: xiaomi, Model: Xiaomi Redmi Note 13 Pro Max 5G, Price: 134350, Avg Rating: 8.3, Is 5G: True, Processor: snapdragon, RAM: 6, Storage: 128
# ID: 632, Brand: xiaomi, Model: Xiaomi Redmi Note 4, Price: 67500, Avg Rating: 6.5, Is 5G: False, Processor: snapdragon, RAM: 4, Storage: 64
# ID: 633, Brand: xiaomi, Model: Xiaomi Redmi Note 8 2021, Price: 65460, Avg Rating: 7.5, Is 5G: False, Processor: helio, RAM: 4, Storage: 64
# ID: 634, Brand: xiaomi, Model: Xiaomi Redmi Note 8 Pro, Price: 111410, Avg Rating: 7.8, Is 5G: False, Processor: helio, RAM: 6, Storage: 64
# ID: 635, Brand: xiaomi, Model: Xiaomi Redmi Note 9, Price: 78560, Avg Rating: 7.5, Is 5G: False, Processor: helio, RAM: 4, Storage: 64
# ID: 636, Brand: xiaomi, Model: Xiaomi Redmi Note 9 Pro, Price: 91740, Avg Rating: 7.5, Is 5G: False, Processor: snapdragon, RAM: 4, Storage: 64
# ID: 637, Brand: xiaomi, Model: Xiaomi Redmi Note 9 Pro (4GB RAM + 128GB), Price: 94620, Avg Rating: 7.7, Is 5G: False, Processor: snapdragon, RAM: 4, Storage: 128
# ID: 638, Brand: xiaomi, Model: Xiaomi Redmi Note 9 Pro Max, Price: 108060, Avg Rating: 8.0, Is 5G: False, Processor: snapdragon, RAM: 6, Storage: 64

# %%
import pandas as pd
from sqlalchemy.orm import Session
from database import engine, SessionLocal
from models.SmartPhone import SmartPhone
from models.ProductModel import ProductModel

# Path to the CSV file
dataset_path = r"C:\Users\prabigya\Desktop\work_here\Recommendo-Personalized-Shopping-Powered-by-LLMs\recommendation_system_ecommerce\dataset\usable_data.csv"

def load_data_from_csv_user(csv_path):
    """Load data from CSV into the SmartPhone table."""
    # Read CSV into a DataFrame
    df = pd.read_csv(csv_path)
    # Open a database session
    session = SessionLocal()
    # session = Session()

    try:
        # Iterate over DataFrame rows and insert into the database
        for _, row in df.iterrows():
            product = ProductModel(
                product_name=row["product_name"],
                product_category_tree=row["product_category_tree"],
                description=row["description"],
                brand=row["brand"],
                discounted_price=row["discounted_price"],
                product_specifications=row["product_specifications"],
                overall_rating=row["overall_rating"],
            )
            session.add(product)

        # Commit the transaction
        session.commit()
        print("Data inserted successfully!")

    except Exception as e:
        # Rollback in case of any error
        session.rollback()
        print("Error occurred:", e)


# if __name__ == "__main__":
#     load_data_from_csv_user(dataset_path)

# %%
import random
# Define sample data
categories = [
    "Clothing", "Electronics", "Fashion", "Books", "Furniture","deodorants","watches","infants wear","mobiles","school supplies","shoes",
    "Appliances", "Toys", "Groceries", "Beauty", "Sports Equipment","tops & tunics","lip care","shirts","cameras"
]

genders = ["Male", "Female", "Other"]

# Generate 100 sample rows
data = []
for i in range(1, 500):
    age = random.randint(18, 40)
    gender = random.choice(genders)
    num_likes = random.randint(2, 7)
    num_dislikes = random.randint(1, 5)
    likes = ", ".join(random.sample(categories, num_likes))
    dislikes = ", ".join(random.sample(categories, num_dislikes))
    feedbacks = ""
    data.append([i, age, gender, likes, dislikes, feedbacks])

# Create DataFrame
columns = ["id", "age", "gender", "likes", "dislikes", "feedbacks"]
df = pd.DataFrame(data, columns=columns)

# Save to CSV
file_path = r"C:\Users\prabigya\Desktop\work_here\Recommendo-Personalized-Shopping-Powered-by-LLMs\recommendation_system_ecommerce\dataset\user_profiles.csv"
df.to_csv(file_path, index=False)

# %%
import pandas as pd
from sqlalchemy.orm import Session
from database import engine, SessionLocal
from models.SmartPhone import SmartPhone
from models.UsersModel import UsersModel

# Path to the CSV file
dataset_path = r"C:\Users\prabigya\Desktop\work_here\Recommendo-Personalized-Shopping-Powered-by-LLMs\recommendation_system_ecommerce\dataset\user_profiles.csv"

def load_data_from_csv_user_profiles(csv_path):
    """Load data from CSV into the SmartPhone table."""
    # Read CSV into a DataFrame
    df = pd.read_csv(csv_path)
    # Open a database session
    session = SessionLocal()
    # session = Session()

    try:
        # Iterate over DataFrame rows and insert into the database
        for _, row in df.iterrows():
            user = UsersModel(
                age=row["age"],
                gender=row["gender"],
                likes=row["likes"],
                dislikes=row["dislikes"],
                feedbacks=row["feedbacks"],
            )
            session.add(user)

        # Commit the transaction
        session.commit()
        print("Data inserted successfully!")

    except Exception as e:
        # Rollback in case of any error
        session.rollback()
        print("Error occurred:", e)


if __name__ == "__main__":
    load_data_from_csv_user_profiles(dataset_path)
# Out:
# 2025-01-15 23:01:51,178 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-01-15 23:01:51,210 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:51,213 INFO sqlalchemy.engine.Engine [generated in 0.00403s (insertmanyvalues) 1/499 (ordered; batch not supported)] (37, 'Other', 'tops & tunics, shoes, Groceries, Fashion, infants wear', 'Fashion, Beauty', nan)
# 2025-01-15 23:01:51,224 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:51,227 INFO sqlalchemy.engine.Engine [insertmanyvalues 2/499 (ordered; batch not supported)] (27, 'Other', 'infants wear, Beauty, deodorants', 'shirts, Appliances, Beauty, infants wear', nan)
# 2025-01-15 23:01:51,230 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:51,232 INFO sqlalchemy.engine.Engine [insertmanyvalues 3/499 (ordered; batch not supported)] (40, 'Other', 'Furniture, shirts, Toys', 'Beauty, lip care, mobiles', nan)
# 2025-01-15 23:01:51,234 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:51,236 INFO sqlalchemy.engine.Engine [insertmanyvalues 4/499 (ordered; batch not supported)] (24, 'Other', 'school supplies, cameras, Beauty, infants wear', 'tops & tunics, shirts, Appliances, shoes, Fashion', nan)
# 2025-01-15 23:01:51,240 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:51,241 INFO sqlalchemy.engine.Engine [insertmanyvalues 5/499 (ordered; batch not supported)] (27, 'Male', 'infants wear, Beauty, Sports Equipment, mobiles, Clothing', 'infants wear', nan)
# 2025-01-15 23:01:51,247 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:51,249 INFO sqlalchemy.engine.Engine [insertmanyvalues 6/499 (ordered; batch not supported)] (18, 'Other', 'infants wear, Sports Equipment, Toys, shoes, Groceries, school supplies, Clothing', 'Toys, Clothing, cameras, Groceries, watches', nan)
# 2025-01-15 23:01:51,251 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:51,252 INFO sqlalchemy.engine.Engine [insertmanyvalues 7/499 (ordered; batch not supported)] (36, 'Male', 'watches, Appliances', 'Clothing, lip care, tops & tunics, shoes, Toys', nan)
# 2025-01-15 23:01:51,255 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:51,256 INFO sqlalchemy.engine.Engine [insertmanyvalues 8/499 (ordered; batch not supported)] (19, 'Male', 'Clothing, Books, school supplies, Fashion, mobiles, infants wear', 'cameras, Toys, tops & tunics, Beauty', nan)
# 2025-01-15 23:01:51,259 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:51,261 INFO sqlalchemy.engine.Engine [insertmanyvalues 9/499 (ordered; batch not supported)] (18, 'Other', 'Sports Equipment, Toys, Clothing', 'cameras, Fashion, Appliances', nan)
# 2025-01-15 23:01:51,265 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:51,267 INFO sqlalchemy.engine.Engine [insertmanyvalues 10/499 (ordered; batch not supported)] (40, 'Other', 'tops & tunics, Groceries, Clothing, cameras, Appliances, infants wear', 'mobiles, Fashion, shirts', nan)
# 2025-01-15 23:01:51,269 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:51,271 INFO sqlalchemy.engine.Engine [insertmanyvalues 11/499 (ordered; batch not supported)] (21, 'Female', 'Appliances, deodorants, Toys, tops & tunics, Sports Equipment', 'Beauty, infants wear, deodorants', nan)
# 2025-01-15 23:01:51,273 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:51,275 INFO sqlalchemy.engine.Engine [insertmanyvalues 12/499 (ordered; batch not supported)] (22, 'Male', 'shoes, Groceries', 'mobiles, Groceries, Fashion, Sports Equipment, lip care', nan)
# 2025-01-15 23:01:51,278 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:51,281 INFO sqlalchemy.engine.Engine [insertmanyvalues 13/499 (ordered; batch not supported)] (39, 'Other', 'shoes, Appliances', 'Clothing, school supplies, Toys', nan)
# 2025-01-15 23:01:51,284 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:51,287 INFO sqlalchemy.engine.Engine [insertmanyvalues 14/499 (ordered; batch not supported)] (40, 'Other', 'Fashion, Electronics, mobiles, Groceries, Appliances, Beauty, Toys', 'Groceries, Furniture, Fashion, Sports Equipment, school supplies', nan)
# 2025-01-15 23:01:51,290 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:51,291 INFO sqlalchemy.engine.Engine [insertmanyvalues 15/499 (ordered; batch not supported)] (34, 'Male', 'shoes, Sports Equipment, Fashion, Toys, cameras, school supplies', 'infants wear', nan)
# 2025-01-15 23:01:51,294 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:51,295 INFO sqlalchemy.engine.Engine [insertmanyvalues 16/499 (ordered; batch not supported)] (26, 'Other', 'Beauty, watches', 'Books, Furniture, Electronics, Beauty, shirts', nan)
# 2025-01-15 23:01:51,299 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:51,300 INFO sqlalchemy.engine.Engine [insertmanyvalues 17/499 (ordered; batch not supported)] (21, 'Female', 'Fashion, Electronics', 'infants wear, Sports Equipment, Appliances, lip care', nan)
# 2025-01-15 23:01:51,303 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:51,304 INFO sqlalchemy.engine.Engine [insertmanyvalues 18/499 (ordered; batch not supported)] (29, 'Male', 'school supplies, tops & tunics, infants wear', 'Clothing, school supplies, Appliances, tops & tunics', nan)
# 2025-01-15 23:01:51,307 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:51,311 INFO sqlalchemy.engine.Engine [insertmanyvalues 19/499 (ordered; batch not supported)] (30, 'Female', 'shirts, tops & tunics, shoes, Furniture', 'Sports Equipment, infants wear, Fashion, Beauty', nan)
# 2025-01-15 23:01:51,313 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:51,315 INFO sqlalchemy.engine.Engine [insertmanyvalues 20/499 (ordered; batch not supported)] (21, 'Male', 'Electronics, Beauty, watches, Fashion', 'Electronics, Beauty, school supplies', nan)
# 2025-01-15 23:01:51,318 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:51,320 INFO sqlalchemy.engine.Engine [insertmanyvalues 21/499 (ordered; batch not supported)] (19, 'Other', 'school supplies, shirts, Beauty', 'mobiles, tops & tunics', nan)
# 2025-01-15 23:01:51,324 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:51,325 INFO sqlalchemy.engine.Engine [insertmanyvalues 22/499 (ordered; batch not supported)] (29, 'Other', 'Fashion, deodorants, Beauty, tops & tunics, cameras, Clothing', 'Beauty, Furniture, Books, Fashion, Clothing', nan)
# 2025-01-15 23:01:51,328 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:51,331 INFO sqlalchemy.engine.Engine [insertmanyvalues 23/499 (ordered; batch not supported)] (34, 'Male', 'watches, mobiles, infants wear, Groceries, Sports Equipment, Toys', 'cameras', nan)
# 2025-01-15 23:01:51,334 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:51,338 INFO sqlalchemy.engine.Engine [insertmanyvalues 24/499 (ordered; batch not supported)] (36, 'Female', 'Electronics, lip care', 'lip care, mobiles, tops & tunics', nan)
# 2025-01-15 23:01:51,341 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:51,343 INFO sqlalchemy.engine.Engine [insertmanyvalues 25/499 (ordered; batch not supported)] (20, 'Male', 'infants wear, shoes, Furniture, Sports Equipment', 'Clothing, mobiles', nan)
# 2025-01-15 23:01:51,345 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:51,348 INFO sqlalchemy.engine.Engine [insertmanyvalues 26/499 (ordered; batch not supported)] (34, 'Male', 'Groceries, shoes', 'shoes', nan)
# 2025-01-15 23:01:51,351 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:51,355 INFO sqlalchemy.engine.Engine [insertmanyvalues 27/499 (ordered; batch not supported)] (23, 'Male', 'deodorants, Electronics, tops & tunics, Groceries, Sports Equipment, Appliances', 'Fashion, Furniture, Appliances, infants wear, Electronics', nan)
# 2025-01-15 23:01:51,358 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:51,361 INFO sqlalchemy.engine.Engine [insertmanyvalues 28/499 (ordered; batch not supported)] (32, 'Male', 'Beauty, infants wear, school supplies, shirts, deodorants, lip care, Toys', 'infants wear, watches, deodorants, Clothing', nan)
# 2025-01-15 23:01:51,363 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:51,365 INFO sqlalchemy.engine.Engine [insertmanyvalues 29/499 (ordered; batch not supported)] (35, 'Other', 'Beauty, Books, shoes, infants wear, school supplies', 'Beauty, Electronics, Toys, tops & tunics, Groceries', nan)
# 2025-01-15 23:01:51,367 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:51,368 INFO sqlalchemy.engine.Engine [insertmanyvalues 30/499 (ordered; batch not supported)] (31, 'Female', 'cameras, Toys', 'shoes', nan)
# 2025-01-15 23:01:51,370 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:51,374 INFO sqlalchemy.engine.Engine [insertmanyvalues 31/499 (ordered; batch not supported)] (34, 'Other', 'tops & tunics, infants wear, Electronics, Appliances, deodorants', 'Toys, Fashion, Beauty, cameras, lip care', nan)
# 2025-01-15 23:01:51,378 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:51,380 INFO sqlalchemy.engine.Engine [insertmanyvalues 32/499 (ordered; batch not supported)] (18, 'Male', 'school supplies, Fashion, Clothing, Electronics, mobiles, tops & tunics', 'Furniture, infants wear, Beauty, tops & tunics', nan)
# 2025-01-15 23:01:51,382 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:51,384 INFO sqlalchemy.engine.Engine [insertmanyvalues 33/499 (ordered; batch not supported)] (22, 'Female', 'Clothing, deodorants, Appliances, Groceries, cameras', 'cameras', nan)
# 2025-01-15 23:01:51,386 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:51,391 INFO sqlalchemy.engine.Engine [insertmanyvalues 34/499 (ordered; batch not supported)] (27, 'Other', 'Groceries, deodorants, school supplies, Sports Equipment, Fashion', 'school supplies, Groceries, Electronics', nan)
# 2025-01-15 23:01:51,395 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:51,397 INFO sqlalchemy.engine.Engine [insertmanyvalues 35/499 (ordered; batch not supported)] (34, 'Male', 'Appliances, cameras, infants wear, Fashion', 'Sports Equipment, Electronics', nan)
# 2025-01-15 23:01:51,400 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:51,402 INFO sqlalchemy.engine.Engine [insertmanyvalues 36/499 (ordered; batch not supported)] (25, 'Male', 'Toys, Fashion, deodorants', 'watches, Furniture', nan)
# 2025-01-15 23:01:51,406 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:51,411 INFO sqlalchemy.engine.Engine [insertmanyvalues 37/499 (ordered; batch not supported)] (37, 'Male', 'Beauty, Books, Toys, mobiles, Electronics, Fashion, watches', 'Sports Equipment, lip care, mobiles, Groceries, deodorants', nan)
# 2025-01-15 23:01:51,414 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:51,416 INFO sqlalchemy.engine.Engine [insertmanyvalues 38/499 (ordered; batch not supported)] (39, 'Other', 'shirts, infants wear, Groceries, Furniture', 'shirts, Groceries, tops & tunics, Books', nan)
# 2025-01-15 23:01:51,418 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:51,421 INFO sqlalchemy.engine.Engine [insertmanyvalues 39/499 (ordered; batch not supported)] (34, 'Female', 'school supplies, Toys, cameras', 'deodorants, Fashion, Appliances', nan)
# 2025-01-15 23:01:51,423 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:51,425 INFO sqlalchemy.engine.Engine [insertmanyvalues 40/499 (ordered; batch not supported)] (24, 'Male', 'Books, Beauty, cameras, Toys, mobiles, Electronics, infants wear', 'watches', nan)
# 2025-01-15 23:01:51,428 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:51,432 INFO sqlalchemy.engine.Engine [insertmanyvalues 41/499 (ordered; batch not supported)] (38, 'Male', 'deodorants, Furniture, mobiles', 'Groceries', nan)
# 2025-01-15 23:01:51,434 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:51,436 INFO sqlalchemy.engine.Engine [insertmanyvalues 42/499 (ordered; batch not supported)] (19, 'Other', 'infants wear, Fashion', 'mobiles, Furniture, shirts', nan)
# 2025-01-15 23:01:51,438 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:51,440 INFO sqlalchemy.engine.Engine [insertmanyvalues 43/499 (ordered; batch not supported)] (40, 'Other', 'Books, Groceries, Electronics, lip care, school supplies', 'Electronics, infants wear, shirts, Fashion', nan)
# 2025-01-15 23:01:51,443 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:51,445 INFO sqlalchemy.engine.Engine [insertmanyvalues 44/499 (ordered; batch not supported)] (29, 'Female', 'Appliances, school supplies, watches, mobiles, tops & tunics, infants wear', 'watches, Beauty, Fashion, Books', nan)
# 2025-01-15 23:01:51,448 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:51,450 INFO sqlalchemy.engine.Engine [insertmanyvalues 45/499 (ordered; batch not supported)] (35, 'Male', 'tops & tunics, Electronics, school supplies, watches', 'Beauty, mobiles', nan)
# 2025-01-15 23:01:51,453 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:51,456 INFO sqlalchemy.engine.Engine [insertmanyvalues 46/499 (ordered; batch not supported)] (22, 'Male', 'deodorants, Fashion, infants wear, tops & tunics, lip care, Books, school supplies', 'deodorants, cameras, school supplies', nan)
# 2025-01-15 23:01:51,458 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:51,460 INFO sqlalchemy.engine.Engine [insertmanyvalues 47/499 (ordered; batch not supported)] (34, 'Male', 'school supplies, Furniture, Beauty', 'Electronics', nan)
# 2025-01-15 23:01:51,476 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:51,476 INFO sqlalchemy.engine.Engine [insertmanyvalues 48/499 (ordered; batch not supported)] (36, 'Female', 'infants wear, cameras, Furniture', 'Clothing', nan)
# 2025-01-15 23:01:51,484 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:51,495 INFO sqlalchemy.engine.Engine [insertmanyvalues 49/499 (ordered; batch not supported)] (23, 'Male', 'cameras, mobiles, Furniture, Beauty, Clothing, school supplies', 'Groceries, cameras, shoes', nan)
# 2025-01-15 23:01:51,503 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:51,505 INFO sqlalchemy.engine.Engine [insertmanyvalues 50/499 (ordered; batch not supported)] (25, 'Male', 'cameras, tops & tunics', 'tops & tunics, shirts, Beauty', nan)
# 2025-01-15 23:01:51,505 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:51,505 INFO sqlalchemy.engine.Engine [insertmanyvalues 51/499 (ordered; batch not supported)] (30, 'Male', 'Clothing, Appliances, lip care, Furniture', 'Fashion, shoes, Beauty, Appliances, school supplies', nan)
# 2025-01-15 23:01:51,505 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:51,513 INFO sqlalchemy.engine.Engine [insertmanyvalues 52/499 (ordered; batch not supported)] (29, 'Other', 'Groceries, school supplies, shoes', 'Clothing, deodorants, Furniture, mobiles', nan)
# 2025-01-15 23:01:51,515 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:51,519 INFO sqlalchemy.engine.Engine [insertmanyvalues 53/499 (ordered; batch not supported)] (40, 'Other', 'lip care, Appliances, shirts', 'Electronics, Fashion, infants wear, shoes, Clothing', nan)
# 2025-01-15 23:01:51,519 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:51,519 INFO sqlalchemy.engine.Engine [insertmanyvalues 54/499 (ordered; batch not supported)] (19, 'Female', 'Books, lip care, tops & tunics, Fashion, shirts, infants wear, Toys', 'cameras', nan)
# 2025-01-15 23:01:51,526 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:51,526 INFO sqlalchemy.engine.Engine [insertmanyvalues 55/499 (ordered; batch not supported)] (35, 'Male', 'Beauty, school supplies, Electronics, Groceries', 'Appliances', nan)
# 2025-01-15 23:01:51,531 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:51,535 INFO sqlalchemy.engine.Engine [insertmanyvalues 56/499 (ordered; batch not supported)] (21, 'Other', 'shirts, shoes', 'shirts, cameras, Clothing, infants wear', nan)
# 2025-01-15 23:01:51,535 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:51,535 INFO sqlalchemy.engine.Engine [insertmanyvalues 57/499 (ordered; batch not supported)] (29, 'Male', 'Toys, Books, watches, shoes, shirts, mobiles, infants wear', 'lip care, Furniture, Sports Equipment', nan)
# 2025-01-15 23:01:51,543 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:51,544 INFO sqlalchemy.engine.Engine [insertmanyvalues 58/499 (ordered; batch not supported)] (32, 'Other', 'shoes, deodorants', 'tops & tunics, Groceries, school supplies', nan)
# 2025-01-15 23:01:51,544 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:51,544 INFO sqlalchemy.engine.Engine [insertmanyvalues 59/499 (ordered; batch not supported)] (20, 'Other', 'shirts, Groceries, shoes, cameras, Toys', 'Electronics, tops & tunics, infants wear, lip care, cameras', nan)
# 2025-01-15 23:01:51,544 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:51,552 INFO sqlalchemy.engine.Engine [insertmanyvalues 60/499 (ordered; batch not supported)] (30, 'Female', 'cameras, Appliances, Furniture, lip care, Electronics', 'Electronics', nan)
# 2025-01-15 23:01:51,553 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:51,553 INFO sqlalchemy.engine.Engine [insertmanyvalues 61/499 (ordered; batch not supported)] (36, 'Male', 'watches, Clothing, Sports Equipment, shirts, deodorants', 'tops & tunics', nan)
# 2025-01-15 23:01:51,562 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:51,564 INFO sqlalchemy.engine.Engine [insertmanyvalues 62/499 (ordered; batch not supported)] (36, 'Male', 'Clothing, watches, mobiles, cameras, deodorants', 'deodorants, lip care, Clothing, Groceries, Fashion', nan)
# 2025-01-15 23:01:51,580 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:51,589 INFO sqlalchemy.engine.Engine [insertmanyvalues 63/499 (ordered; batch not supported)] (29, 'Female', 'tops & tunics, mobiles, Groceries, watches', 'Clothing, Fashion, infants wear, school supplies', nan)
# 2025-01-15 23:01:51,589 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:51,594 INFO sqlalchemy.engine.Engine [insertmanyvalues 64/499 (ordered; batch not supported)] (29, 'Other', 'Toys, Electronics, Books, Beauty', 'Clothing, Toys, school supplies, cameras, watches', nan)
# 2025-01-15 23:01:51,594 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:51,594 INFO sqlalchemy.engine.Engine [insertmanyvalues 65/499 (ordered; batch not supported)] (33, 'Male', 'Sports Equipment, watches, mobiles', 'mobiles', nan)
# 2025-01-15 23:01:51,602 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:51,604 INFO sqlalchemy.engine.Engine [insertmanyvalues 66/499 (ordered; batch not supported)] (28, 'Other', 'deodorants, infants wear, Appliances, Clothing, Groceries, shirts, school supplies', 'Appliances, cameras, Furniture, tops & tunics', nan)
# 2025-01-15 23:01:51,606 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:51,608 INFO sqlalchemy.engine.Engine [insertmanyvalues 67/499 (ordered; batch not supported)] (28, 'Other', 'Electronics, shirts, watches, shoes, Toys, Books', 'shoes, mobiles, lip care, tops & tunics, Fashion', nan)
# 2025-01-15 23:01:51,610 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:51,612 INFO sqlalchemy.engine.Engine [insertmanyvalues 68/499 (ordered; batch not supported)] (20, 'Other', 'Electronics, deodorants, watches, cameras', 'Electronics, watches, shoes', nan)
# 2025-01-15 23:01:51,613 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:51,614 INFO sqlalchemy.engine.Engine [insertmanyvalues 69/499 (ordered; batch not supported)] (28, 'Male', 'Furniture, Fashion, Clothing, cameras, Books, Beauty, school supplies', 'deodorants, Beauty, school supplies, Furniture, Groceries', nan)
# 2025-01-15 23:01:51,616 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:51,618 INFO sqlalchemy.engine.Engine [insertmanyvalues 70/499 (ordered; batch not supported)] (38, 'Male', 'shirts, Furniture', 'Fashion, tops & tunics', nan)
# 2025-01-15 23:01:51,619 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:51,621 INFO sqlalchemy.engine.Engine [insertmanyvalues 71/499 (ordered; batch not supported)] (30, 'Female', 'Beauty, tops & tunics', 'cameras, Beauty, tops & tunics', nan)
# 2025-01-15 23:01:51,626 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:51,634 INFO sqlalchemy.engine.Engine [insertmanyvalues 72/499 (ordered; batch not supported)] (20, 'Male', 'shoes, Sports Equipment, watches, Electronics', 'school supplies, shirts, Sports Equipment', nan)
# 2025-01-15 23:01:51,639 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:51,642 INFO sqlalchemy.engine.Engine [insertmanyvalues 73/499 (ordered; batch not supported)] (38, 'Other', 'Appliances, school supplies', 'mobiles, Toys, shoes, Clothing, cameras', nan)
# 2025-01-15 23:01:51,644 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:51,646 INFO sqlalchemy.engine.Engine [insertmanyvalues 74/499 (ordered; batch not supported)] (27, 'Female', 'tops & tunics, shoes, Books', 'Beauty', nan)
# 2025-01-15 23:01:51,649 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:51,650 INFO sqlalchemy.engine.Engine [insertmanyvalues 75/499 (ordered; batch not supported)] (18, 'Female', 'Fashion, Beauty, infants wear, Furniture', 'Toys, infants wear, Books, Groceries, deodorants', nan)
# 2025-01-15 23:01:51,652 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:51,653 INFO sqlalchemy.engine.Engine [insertmanyvalues 76/499 (ordered; batch not supported)] (21, 'Male', 'cameras, Electronics, mobiles, Furniture, Appliances, tops & tunics', 'Electronics, watches', nan)
# 2025-01-15 23:01:51,655 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:51,656 INFO sqlalchemy.engine.Engine [insertmanyvalues 77/499 (ordered; batch not supported)] (32, 'Other', 'school supplies, Groceries, Sports Equipment, shirts, mobiles, cameras, Beauty', 'cameras, Books, Groceries', nan)
# 2025-01-15 23:01:51,657 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:51,658 INFO sqlalchemy.engine.Engine [insertmanyvalues 78/499 (ordered; batch not supported)] (39, 'Male', 'lip care, mobiles', 'shoes, Furniture, Books, Clothing, Fashion', nan)
# 2025-01-15 23:01:51,661 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:51,664 INFO sqlalchemy.engine.Engine [insertmanyvalues 79/499 (ordered; batch not supported)] (19, 'Female', 'mobiles, Toys, lip care, Clothing, shoes, infants wear', 'Electronics', nan)
# 2025-01-15 23:01:51,665 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:51,666 INFO sqlalchemy.engine.Engine [insertmanyvalues 80/499 (ordered; batch not supported)] (35, 'Male', 'shirts, Appliances', 'Groceries, school supplies', nan)
# 2025-01-15 23:01:51,668 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:51,671 INFO sqlalchemy.engine.Engine [insertmanyvalues 81/499 (ordered; batch not supported)] (26, 'Male', 'mobiles, Sports Equipment', 'lip care, tops & tunics, Books, school supplies', nan)
# 2025-01-15 23:01:51,673 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:51,675 INFO sqlalchemy.engine.Engine [insertmanyvalues 82/499 (ordered; batch not supported)] (32, 'Other', 'tops & tunics, watches, infants wear, Groceries, Fashion', 'shirts, shoes, cameras, Groceries, infants wear', nan)
# 2025-01-15 23:01:51,677 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:51,679 INFO sqlalchemy.engine.Engine [insertmanyvalues 83/499 (ordered; batch not supported)] (35, 'Other', 'mobiles, tops & tunics', 'cameras, tops & tunics, Appliances', nan)
# 2025-01-15 23:01:51,681 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:51,682 INFO sqlalchemy.engine.Engine [insertmanyvalues 84/499 (ordered; batch not supported)] (29, 'Other', 'Electronics, Fashion, Beauty, shoes, Furniture, deodorants', 'watches', nan)
# 2025-01-15 23:01:51,684 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:51,687 INFO sqlalchemy.engine.Engine [insertmanyvalues 85/499 (ordered; batch not supported)] (34, 'Female', 'Fashion, Books, cameras, Groceries, Toys, mobiles, Sports Equipment', 'Electronics, infants wear', nan)
# 2025-01-15 23:01:51,689 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:51,693 INFO sqlalchemy.engine.Engine [insertmanyvalues 86/499 (ordered; batch not supported)] (38, 'Male', 'watches, infants wear, tops & tunics', 'Furniture, deodorants, shoes', nan)
# 2025-01-15 23:01:51,695 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:51,696 INFO sqlalchemy.engine.Engine [insertmanyvalues 87/499 (ordered; batch not supported)] (25, 'Male', 'tops & tunics, shoes, Toys', 'Furniture, mobiles, lip care', nan)
# 2025-01-15 23:01:51,698 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:51,699 INFO sqlalchemy.engine.Engine [insertmanyvalues 88/499 (ordered; batch not supported)] (40, 'Female', 'Clothing, lip care, Electronics, Beauty, Groceries, cameras', 'deodorants, Books', nan)
# 2025-01-15 23:01:51,703 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:51,704 INFO sqlalchemy.engine.Engine [insertmanyvalues 89/499 (ordered; batch not supported)] (31, 'Female', 'Electronics, Clothing, shoes, deodorants, lip care, Fashion', 'infants wear, cameras, tops & tunics', nan)
# 2025-01-15 23:01:51,707 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:51,709 INFO sqlalchemy.engine.Engine [insertmanyvalues 90/499 (ordered; batch not supported)] (30, 'Other', 'Electronics, deodorants, Sports Equipment, shoes', 'Furniture, Toys, mobiles, shirts', nan)
# 2025-01-15 23:01:51,712 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:51,715 INFO sqlalchemy.engine.Engine [insertmanyvalues 91/499 (ordered; batch not supported)] (29, 'Other', 'Fashion, Clothing, Books, infants wear', 'Beauty, Toys, mobiles, shoes', nan)
# 2025-01-15 23:01:51,716 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:51,717 INFO sqlalchemy.engine.Engine [insertmanyvalues 92/499 (ordered; batch not supported)] (22, 'Female', 'Appliances, Electronics', 'shirts', nan)
# 2025-01-15 23:01:51,720 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:51,722 INFO sqlalchemy.engine.Engine [insertmanyvalues 93/499 (ordered; batch not supported)] (34, 'Female', 'Sports Equipment, lip care, Books', 'Clothing, lip care, watches, Toys', nan)
# 2025-01-15 23:01:51,725 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:51,726 INFO sqlalchemy.engine.Engine [insertmanyvalues 94/499 (ordered; batch not supported)] (35, 'Female', 'Beauty, Appliances, Clothing, Fashion', 'Beauty, Sports Equipment, Groceries', nan)
# 2025-01-15 23:01:51,728 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:51,730 INFO sqlalchemy.engine.Engine [insertmanyvalues 95/499 (ordered; batch not supported)] (18, 'Female', 'cameras, Furniture, infants wear, Sports Equipment, Appliances, watches, shoes', 'Furniture, school supplies, Electronics, Fashion', nan)
# 2025-01-15 23:01:51,732 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:51,734 INFO sqlalchemy.engine.Engine [insertmanyvalues 96/499 (ordered; batch not supported)] (24, 'Male', 'Clothing, watches, school supplies, Sports Equipment, Appliances, shirts, tops & tunics', 'mobiles, Sports Equipment, Fashion', nan)
# 2025-01-15 23:01:51,737 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:51,739 INFO sqlalchemy.engine.Engine [insertmanyvalues 97/499 (ordered; batch not supported)] (30, 'Other', 'tops & tunics, infants wear, Electronics, Groceries', 'watches, Appliances', nan)
# 2025-01-15 23:01:51,743 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:51,744 INFO sqlalchemy.engine.Engine [insertmanyvalues 98/499 (ordered; batch not supported)] (30, 'Female', 'Electronics, mobiles, tops & tunics, deodorants, Furniture, Fashion', 'Books', nan)
# 2025-01-15 23:01:51,746 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:51,747 INFO sqlalchemy.engine.Engine [insertmanyvalues 99/499 (ordered; batch not supported)] (18, 'Male', 'Sports Equipment, infants wear, Clothing, Books', 'Toys', nan)
# 2025-01-15 23:01:51,749 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:51,751 INFO sqlalchemy.engine.Engine [insertmanyvalues 100/499 (ordered; batch not supported)] (31, 'Male', 'Toys, Appliances, Books, Electronics', 'Electronics, school supplies, cameras, Sports Equipment, mobiles', nan)
# 2025-01-15 23:01:51,753 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:51,755 INFO sqlalchemy.engine.Engine [insertmanyvalues 101/499 (ordered; batch not supported)] (24, 'Other', 'shoes, mobiles, school supplies, deodorants, tops & tunics, Furniture, Books', 'shirts, Groceries, Furniture', nan)
# 2025-01-15 23:01:51,757 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:51,759 INFO sqlalchemy.engine.Engine [insertmanyvalues 102/499 (ordered; batch not supported)] (40, 'Male', 'deodorants, Appliances', 'deodorants', nan)
# 2025-01-15 23:01:51,761 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:51,763 INFO sqlalchemy.engine.Engine [insertmanyvalues 103/499 (ordered; batch not supported)] (34, 'Male', 'shirts, Clothing', 'mobiles, Appliances, Clothing', nan)
# 2025-01-15 23:01:51,765 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:51,766 INFO sqlalchemy.engine.Engine [insertmanyvalues 104/499 (ordered; batch not supported)] (31, 'Other', 'watches, Beauty, Fashion, Appliances', 'Groceries, Clothing, Toys, mobiles, school supplies', nan)
# 2025-01-15 23:01:51,767 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:51,768 INFO sqlalchemy.engine.Engine [insertmanyvalues 105/499 (ordered; batch not supported)] (22, 'Male', 'Sports Equipment, deodorants, shirts, Furniture, Books, cameras, Toys', 'shoes, Appliances, cameras, school supplies', nan)
# 2025-01-15 23:01:51,770 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:51,771 INFO sqlalchemy.engine.Engine [insertmanyvalues 106/499 (ordered; batch not supported)] (38, 'Female', 'Books, shoes, deodorants, Beauty, watches', 'Sports Equipment, Furniture, Groceries, tops & tunics', nan)
# 2025-01-15 23:01:51,773 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:51,776 INFO sqlalchemy.engine.Engine [insertmanyvalues 107/499 (ordered; batch not supported)] (37, 'Male', 'Books, Sports Equipment, Beauty', 'Fashion, shirts, deodorants', nan)
# 2025-01-15 23:01:51,780 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:51,782 INFO sqlalchemy.engine.Engine [insertmanyvalues 108/499 (ordered; batch not supported)] (31, 'Male', 'mobiles, Groceries', 'Clothing, deodorants', nan)
# 2025-01-15 23:01:51,784 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:51,787 INFO sqlalchemy.engine.Engine [insertmanyvalues 109/499 (ordered; batch not supported)] (25, 'Other', 'tops & tunics, Beauty, Toys, Sports Equipment', 'infants wear, Appliances', nan)
# 2025-01-15 23:01:51,789 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:51,790 INFO sqlalchemy.engine.Engine [insertmanyvalues 110/499 (ordered; batch not supported)] (32, 'Other', 'lip care, shoes, Clothing', 'tops & tunics, lip care', nan)
# 2025-01-15 23:01:51,791 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:51,793 INFO sqlalchemy.engine.Engine [insertmanyvalues 111/499 (ordered; batch not supported)] (25, 'Other', 'shirts, watches, Electronics, Clothing, school supplies', 'Groceries, lip care, Books, Electronics', nan)
# 2025-01-15 23:01:51,796 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:51,798 INFO sqlalchemy.engine.Engine [insertmanyvalues 112/499 (ordered; batch not supported)] (25, 'Other', 'Books, cameras, Sports Equipment, Groceries, shirts', 'Toys, Fashion, Groceries, cameras', nan)
# 2025-01-15 23:01:51,800 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:51,802 INFO sqlalchemy.engine.Engine [insertmanyvalues 113/499 (ordered; batch not supported)] (21, 'Male', 'Beauty, Furniture, Clothing, Fashion', 'cameras, Sports Equipment, Groceries, Electronics, school supplies', nan)
# 2025-01-15 23:01:51,804 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:51,806 INFO sqlalchemy.engine.Engine [insertmanyvalues 114/499 (ordered; batch not supported)] (29, 'Other', 'watches, Toys, tops & tunics, shoes, Groceries', 'lip care, shirts, cameras, Appliances', nan)
# 2025-01-15 23:01:51,809 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:51,810 INFO sqlalchemy.engine.Engine [insertmanyvalues 115/499 (ordered; batch not supported)] (30, 'Male', 'Furniture, Clothing, deodorants, Beauty', 'Fashion, cameras, tops & tunics', nan)
# 2025-01-15 23:01:51,813 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:51,815 INFO sqlalchemy.engine.Engine [insertmanyvalues 116/499 (ordered; batch not supported)] (30, 'Female', 'Furniture, watches, Beauty, cameras', 'lip care, Toys, cameras', nan)
# 2025-01-15 23:01:51,816 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:51,817 INFO sqlalchemy.engine.Engine [insertmanyvalues 117/499 (ordered; batch not supported)] (25, 'Male', 'tops & tunics, deodorants, lip care, infants wear, Toys', 'Appliances, Sports Equipment', nan)
# 2025-01-15 23:01:51,818 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:51,820 INFO sqlalchemy.engine.Engine [insertmanyvalues 118/499 (ordered; batch not supported)] (26, 'Female', 'Toys, Fashion, shoes', 'mobiles, Beauty, deodorants', nan)
# 2025-01-15 23:01:51,824 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:51,825 INFO sqlalchemy.engine.Engine [insertmanyvalues 119/499 (ordered; batch not supported)] (36, 'Other', 'Furniture, Beauty, Clothing, Toys', 'school supplies, shoes, cameras', nan)
# 2025-01-15 23:01:51,827 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:51,830 INFO sqlalchemy.engine.Engine [insertmanyvalues 120/499 (ordered; batch not supported)] (31, 'Other', 'shirts, Appliances, mobiles, school supplies, Clothing, lip care', 'Books, mobiles, deodorants, watches, shoes', nan)
# 2025-01-15 23:01:51,832 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:51,833 INFO sqlalchemy.engine.Engine [insertmanyvalues 121/499 (ordered; batch not supported)] (21, 'Female', 'school supplies, watches, Sports Equipment, Clothing', 'mobiles, deodorants, tops & tunics, Sports Equipment', nan)
# 2025-01-15 23:01:51,837 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:51,851 INFO sqlalchemy.engine.Engine [insertmanyvalues 122/499 (ordered; batch not supported)] (30, 'Other', 'Appliances, Furniture, Fashion, school supplies', 'Toys, Furniture, Books, Electronics', nan)
# 2025-01-15 23:01:51,859 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:51,862 INFO sqlalchemy.engine.Engine [insertmanyvalues 123/499 (ordered; batch not supported)] (38, 'Female', 'Furniture, infants wear, shoes, school supplies, cameras, Clothing', 'deodorants, Clothing, lip care, Furniture, shoes', nan)
# 2025-01-15 23:01:51,863 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:51,865 INFO sqlalchemy.engine.Engine [insertmanyvalues 124/499 (ordered; batch not supported)] (25, 'Female', 'Sports Equipment, lip care, Clothing, Appliances, Beauty', 'Beauty, Sports Equipment, Toys', nan)
# 2025-01-15 23:01:51,867 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:51,870 INFO sqlalchemy.engine.Engine [insertmanyvalues 125/499 (ordered; batch not supported)] (38, 'Female', 'Electronics, Sports Equipment, Appliances, cameras, mobiles, Furniture', 'tops & tunics, infants wear, Electronics, cameras, school supplies', nan)
# 2025-01-15 23:01:51,872 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:51,874 INFO sqlalchemy.engine.Engine [insertmanyvalues 126/499 (ordered; batch not supported)] (19, 'Male', 'Clothing, Electronics, school supplies, tops & tunics, cameras', 'mobiles, shoes, Furniture', nan)
# 2025-01-15 23:01:51,876 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:51,879 INFO sqlalchemy.engine.Engine [insertmanyvalues 127/499 (ordered; batch not supported)] (25, 'Male', 'Electronics, watches', 'Furniture, Groceries', nan)
# 2025-01-15 23:01:51,880 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:51,883 INFO sqlalchemy.engine.Engine [insertmanyvalues 128/499 (ordered; batch not supported)] (29, 'Female', 'mobiles, watches, Furniture, shirts, Beauty, deodorants', 'Beauty, shirts, lip care, Toys, Furniture', nan)
# 2025-01-15 23:01:51,885 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:51,887 INFO sqlalchemy.engine.Engine [insertmanyvalues 129/499 (ordered; batch not supported)] (18, 'Female', 'tops & tunics, infants wear, mobiles', 'Sports Equipment, lip care', nan)
# 2025-01-15 23:01:51,889 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:51,893 INFO sqlalchemy.engine.Engine [insertmanyvalues 130/499 (ordered; batch not supported)] (25, 'Other', 'Toys, Groceries, Books, mobiles', 'Appliances, Toys, Electronics', nan)
# 2025-01-15 23:01:51,899 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:51,900 INFO sqlalchemy.engine.Engine [insertmanyvalues 131/499 (ordered; batch not supported)] (21, 'Female', 'deodorants, lip care, Beauty, school supplies, tops & tunics', 'shirts, school supplies, Sports Equipment, tops & tunics, infants wear', nan)
# ...
# 2025-01-15 23:01:53,737 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:53,739 INFO sqlalchemy.engine.Engine [insertmanyvalues 457/499 (ordered; batch not supported)] (21, 'Female', 'Clothing, Groceries, mobiles, school supplies, Books, Fashion, infants wear', 'watches, shoes, shirts, Sports Equipment', nan)
# 2025-01-15 23:01:53,740 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:53,742 INFO sqlalchemy.engine.Engine [insertmanyvalues 458/499 (ordered; batch not supported)] (34, 'Other', 'Beauty, deodorants, Appliances, Clothing, infants wear, Books', 'Fashion, Toys, deodorants, Furniture', nan)
# 2025-01-15 23:01:53,744 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:53,746 INFO sqlalchemy.engine.Engine [insertmanyvalues 459/499 (ordered; batch not supported)] (26, 'Female', 'tops & tunics, watches, Clothing, shoes, Furniture, school supplies', 'lip care', nan)
# 2025-01-15 23:01:53,748 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:53,750 INFO sqlalchemy.engine.Engine [insertmanyvalues 460/499 (ordered; batch not supported)] (29, 'Other', 'infants wear, mobiles, Sports Equipment, cameras', 'cameras, Appliances, deodorants, Books, watches', nan)
# 2025-01-15 23:01:53,753 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:53,756 INFO sqlalchemy.engine.Engine [insertmanyvalues 461/499 (ordered; batch not supported)] (29, 'Male', 'lip care, infants wear, Toys, tops & tunics, Appliances', 'shirts, Electronics, school supplies', nan)
# 2025-01-15 23:01:53,756 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:53,764 INFO sqlalchemy.engine.Engine [insertmanyvalues 462/499 (ordered; batch not supported)] (23, 'Female', 'Beauty, shoes, Fashion, shirts', 'lip care, Books, cameras, infants wear, Furniture', nan)
# 2025-01-15 23:01:53,768 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:53,786 INFO sqlalchemy.engine.Engine [insertmanyvalues 463/499 (ordered; batch not supported)] (40, 'Other', 'Beauty, Furniture', 'tops & tunics, Sports Equipment, Groceries', nan)
# 2025-01-15 23:01:53,812 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:53,814 INFO sqlalchemy.engine.Engine [insertmanyvalues 464/499 (ordered; batch not supported)] (40, 'Female', 'mobiles, watches, shoes, Fashion', 'Sports Equipment, lip care, Groceries, Electronics, Beauty', nan)
# 2025-01-15 23:01:53,814 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:53,814 INFO sqlalchemy.engine.Engine [insertmanyvalues 465/499 (ordered; batch not supported)] (34, 'Female', 'Furniture, tops & tunics, deodorants, Groceries, lip care', 'Appliances, Beauty', nan)
# 2025-01-15 23:01:53,822 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:53,836 INFO sqlalchemy.engine.Engine [insertmanyvalues 466/499 (ordered; batch not supported)] (29, 'Female', 'tops & tunics, Electronics, shirts, infants wear, school supplies, Clothing', 'shirts, Clothing, Beauty, mobiles, deodorants', nan)
# 2025-01-15 23:01:53,838 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:53,899 INFO sqlalchemy.engine.Engine [insertmanyvalues 467/499 (ordered; batch not supported)] (39, 'Male', 'Beauty, cameras', 'Clothing, Toys, shirts', nan)
# 2025-01-15 23:01:53,907 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:53,909 INFO sqlalchemy.engine.Engine [insertmanyvalues 468/499 (ordered; batch not supported)] (33, 'Other', 'lip care, school supplies, Groceries', 'Electronics, shirts, mobiles', nan)
# 2025-01-15 23:01:53,909 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:53,909 INFO sqlalchemy.engine.Engine [insertmanyvalues 469/499 (ordered; batch not supported)] (40, 'Other', 'cameras, Books, Electronics, tops & tunics', 'infants wear', nan)
# 2025-01-15 23:01:53,917 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:53,919 INFO sqlalchemy.engine.Engine [insertmanyvalues 470/499 (ordered; batch not supported)] (25, 'Other', 'cameras, shirts, tops & tunics, mobiles, Fashion, school supplies, Sports Equipment', 'tops & tunics, lip care, Toys, shoes', nan)
# 2025-01-15 23:01:53,920 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:53,920 INFO sqlalchemy.engine.Engine [insertmanyvalues 471/499 (ordered; batch not supported)] (29, 'Other', 'Sports Equipment, Books, Toys, mobiles, infants wear, Beauty, Groceries', 'Sports Equipment', nan)
# 2025-01-15 23:01:53,920 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:53,930 INFO sqlalchemy.engine.Engine [insertmanyvalues 472/499 (ordered; batch not supported)] (18, 'Other', 'Toys, shoes', 'lip care, shoes, Sports Equipment, tops & tunics, infants wear', nan)
# 2025-01-15 23:01:53,932 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:53,934 INFO sqlalchemy.engine.Engine [insertmanyvalues 473/499 (ordered; batch not supported)] (27, 'Female', 'tops & tunics, mobiles, school supplies', 'infants wear, Toys, Clothing, mobiles, shirts', nan)
# 2025-01-15 23:01:53,936 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:53,938 INFO sqlalchemy.engine.Engine [insertmanyvalues 474/499 (ordered; batch not supported)] (19, 'Other', 'Books, Toys, Fashion', 'watches, tops & tunics, school supplies, Furniture', nan)
# 2025-01-15 23:01:53,940 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:53,943 INFO sqlalchemy.engine.Engine [insertmanyvalues 475/499 (ordered; batch not supported)] (25, 'Other', 'tops & tunics, Toys, cameras', 'school supplies', nan)
# 2025-01-15 23:01:53,946 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:53,948 INFO sqlalchemy.engine.Engine [insertmanyvalues 476/499 (ordered; batch not supported)] (20, 'Other', 'mobiles, Appliances, school supplies, Furniture, Groceries', 'Books, Appliances, lip care, deodorants, Sports Equipment', nan)
# 2025-01-15 23:01:53,966 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:53,966 INFO sqlalchemy.engine.Engine [insertmanyvalues 477/499 (ordered; batch not supported)] (38, 'Male', 'Groceries, shirts', 'Groceries, Beauty, Clothing', nan)
# 2025-01-15 23:01:53,971 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:53,973 INFO sqlalchemy.engine.Engine [insertmanyvalues 478/499 (ordered; batch not supported)] (20, 'Male', 'tops & tunics, Groceries, Fashion, watches, Beauty, infants wear', 'Sports Equipment', nan)
# 2025-01-15 23:01:53,973 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:53,979 INFO sqlalchemy.engine.Engine [insertmanyvalues 479/499 (ordered; batch not supported)] (30, 'Female', 'mobiles, tops & tunics, shirts', 'infants wear, Electronics, Beauty, deodorants', nan)
# 2025-01-15 23:01:53,981 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:53,983 INFO sqlalchemy.engine.Engine [insertmanyvalues 480/499 (ordered; batch not supported)] (22, 'Other', 'tops & tunics, infants wear', 'mobiles, Beauty, watches', nan)
# 2025-01-15 23:01:53,986 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:53,987 INFO sqlalchemy.engine.Engine [insertmanyvalues 481/499 (ordered; batch not supported)] (35, 'Other', 'shirts, Clothing, cameras, watches, Electronics, tops & tunics, Beauty', 'lip care', nan)
# 2025-01-15 23:01:53,987 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:53,994 INFO sqlalchemy.engine.Engine [insertmanyvalues 482/499 (ordered; batch not supported)] (37, 'Female', 'deodorants, Sports Equipment, Beauty, lip care, watches, shirts, Toys', 'Groceries, Books, shoes, mobiles', nan)
# 2025-01-15 23:01:53,994 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:53,999 INFO sqlalchemy.engine.Engine [insertmanyvalues 483/499 (ordered; batch not supported)] (27, 'Male', 'watches, Electronics, Clothing, Groceries, Appliances', 'cameras, deodorants, Groceries, tops & tunics, Toys', nan)
# 2025-01-15 23:01:54,002 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:54,002 INFO sqlalchemy.engine.Engine [insertmanyvalues 484/499 (ordered; batch not supported)] (25, 'Female', 'school supplies, cameras', 'Sports Equipment, Toys, shirts, Appliances', nan)
# 2025-01-15 23:01:54,007 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:54,010 INFO sqlalchemy.engine.Engine [insertmanyvalues 485/499 (ordered; batch not supported)] (19, 'Male', 'lip care, shoes', 'tops & tunics, Toys, Sports Equipment', nan)
# 2025-01-15 23:01:54,012 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:54,018 INFO sqlalchemy.engine.Engine [insertmanyvalues 486/499 (ordered; batch not supported)] (36, 'Female', 'deodorants, watches, Furniture, school supplies, Beauty', 'Books, school supplies', nan)
# 2025-01-15 23:01:54,020 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:54,023 INFO sqlalchemy.engine.Engine [insertmanyvalues 487/499 (ordered; batch not supported)] (28, 'Other', 'deodorants, cameras, Appliances, infants wear, tops & tunics, Toys', 'deodorants, tops & tunics, school supplies', nan)
# 2025-01-15 23:01:54,024 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:54,026 INFO sqlalchemy.engine.Engine [insertmanyvalues 488/499 (ordered; batch not supported)] (39, 'Female', 'lip care, Groceries, shirts, Furniture, Toys, Fashion, school supplies', 'school supplies, Beauty', nan)
# 2025-01-15 23:01:54,028 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:54,028 INFO sqlalchemy.engine.Engine [insertmanyvalues 489/499 (ordered; batch not supported)] (36, 'Male', 'Groceries, Appliances, Electronics, mobiles, cameras', 'shirts', nan)
# 2025-01-15 23:01:54,035 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:54,038 INFO sqlalchemy.engine.Engine [insertmanyvalues 490/499 (ordered; batch not supported)] (34, 'Female', 'cameras, Books, Electronics, Furniture', 'school supplies, Sports Equipment, Appliances', nan)
# 2025-01-15 23:01:54,040 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:54,043 INFO sqlalchemy.engine.Engine [insertmanyvalues 491/499 (ordered; batch not supported)] (25, 'Male', 'shoes, school supplies, Sports Equipment, Appliances, Electronics, deodorants', 'mobiles, Beauty, watches', nan)
# 2025-01-15 23:01:54,047 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:54,047 INFO sqlalchemy.engine.Engine [insertmanyvalues 492/499 (ordered; batch not supported)] (18, 'Male', 'watches, Appliances, Sports Equipment, deodorants, tops & tunics, shirts', 'school supplies, tops & tunics, Clothing, Electronics', nan)
# 2025-01-15 23:01:54,052 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:54,054 INFO sqlalchemy.engine.Engine [insertmanyvalues 493/499 (ordered; batch not supported)] (25, 'Male', 'Fashion, shoes', 'mobiles, Furniture, Electronics', nan)
# 2025-01-15 23:01:54,056 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:54,058 INFO sqlalchemy.engine.Engine [insertmanyvalues 494/499 (ordered; batch not supported)] (21, 'Female', 'infants wear, deodorants, school supplies', 'Books, shirts', nan)
# 2025-01-15 23:01:54,061 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:54,064 INFO sqlalchemy.engine.Engine [insertmanyvalues 495/499 (ordered; batch not supported)] (27, 'Male', 'Electronics, Books, school supplies, Toys', 'shirts, mobiles, Furniture, Books, shoes', nan)
# 2025-01-15 23:01:54,066 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:54,066 INFO sqlalchemy.engine.Engine [insertmanyvalues 496/499 (ordered; batch not supported)] (31, 'Female', 'Furniture, Sports Equipment, Beauty, Electronics, shirts, Appliances', 'infants wear, Beauty, school supplies, cameras', nan)
# 2025-01-15 23:01:54,066 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:54,071 INFO sqlalchemy.engine.Engine [insertmanyvalues 497/499 (ordered; batch not supported)] (31, 'Male', 'infants wear, watches, deodorants, Books, cameras', 'shoes, cameras, shirts', nan)
# 2025-01-15 23:01:54,087 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:54,088 INFO sqlalchemy.engine.Engine [insertmanyvalues 498/499 (ordered; batch not supported)] (37, 'Male', 'Sports Equipment, Toys, Clothing, Books, school supplies, Groceries', 'shirts, Beauty, Sports Equipment, Electronics', nan)
# 2025-01-15 23:01:54,091 INFO sqlalchemy.engine.Engine INSERT INTO users (age, gender, likes, dislikes, feedbacks) VALUES (?, ?, ?, ?, ?) RETURNING id
# 2025-01-15 23:01:54,094 INFO sqlalchemy.engine.Engine [insertmanyvalues 499/499 (ordered; batch not supported)] (30, 'Other', 'Furniture, deodorants, Books, infants wear, lip care', 'lip care', nan)
# 2025-01-15 23:01:54,121 INFO sqlalchemy.engine.Engine COMMIT
# Data inserted successfully!
